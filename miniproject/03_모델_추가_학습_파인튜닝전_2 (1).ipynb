# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/satisfaction.png'/></center>

# %% [markdown]
# ### **고객 만족도 예측을 통한 서비스 개선**
# # **단계 3: 모델 추가 학습**

# %% [markdown]
# ## **미션 설명**
#
# - 이번 단계에서는 다음과 같이 3개의 미션을 수행합니다.

# %% [markdown]
# ### 미션 8: 전처리 파이프라인 만들기
#
# - 새로운 학습용/검증용 데이터에 대해 매번 전처리 작업을 수행해야 합니다.
# - 반복되는 전처리 작업은 비효율적인 업무 중 하나입니다.
# - 이러한 문제를 해결하기 위해 다음과 같은 처리를 일괄 수행하는 파이프라인 함수를 만듭니다.
#     - 결측치 처리
#     - Target 값 0/1로 변경
#     - 불필요한 변수 제거
#     - 라벨 인코딩
#     - 가변수화
#     - x, y 분리
#     - x 스케일링 등

# %% [markdown]
# ### 미션 9: 기본 모델로 예측 및 평가
#
# - 이전 과정에서 만든 모델이 기본 모델(Base Model)입니다.
# - 새로 전달 받은 평가용 데이터로 기존에 만든 모델의 성능을 평가해봅니다.

# %% [markdown]
# ### 미션 10: 추가 학습
#
# - 문제 상황에 맞게 가장 적절한 방법으로 모델 추가 학습을 진행합니다.
# - 추가 학습 후 이전에 평가했던 새로운 평가 데이터로 다시 평가해 성능 향상을 확인합니다.

# %% [markdown]
# ## **※ 코드 셀은 충분히 추가해 사용합니다.**

# %% [markdown]
# ## **1. 환경설정**

# %% [markdown]
# ### (1) 구글 드라이브 연결 및 경로 설정
#
# - 다음 구문을 실행에 구글 코랩에서 사용 가능하게 연결합니다.

# %%
# 구글 드라이브 연결 & 패스 지정
import sys
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    path = '/content/drive/MyDrive/project01/'
else:
    path = ''
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### (2) 라이브러리 불러오기
#
# - 이후에 사용할 라이브러리를 모두 불러옵니다.

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import *
from sklearn.utils import class_weight


from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.backend import clear_session
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

import joblib
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### (3) 학습 곡선 시각화 함수 만들기
#
# - 모델링 수행 시 학습 상황을 시각화해 확인하기 위한 함수를 만듭니다.

# %%
# 함수 만들기
def dl_history_plot(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history['loss'], label='Train Loss', marker='.')
    plt.plot(history['val_loss'], label='Validation Loss', marker='.')

    plt.title('Learning Curve', size=15, pad=20)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %% [markdown]
# ### (4) 기본 모델 및 데이터 불러오기
#
# - 우선 이전 과정에서 저장한 모델을 불러와 base_model로 선언합니다.
#     - path + 'base_model.keras' →  base_model
# - **load_model()** 함수를 사용합니다.

# %%
# 모델 불러오기
base_model = load_model(path + 'base_model.keras')

# %% [markdown]
# - 이전 과정에서 저장한 스케일러를 불러와 scaler 변수에 저장합니다.
#     - path + 'scaler.pkl' →  scaler
# - **joblib.load()** 함수를 사용합니다.

# %%
# 스케일러 불러오기
scaler = joblib.load(path + 'scaler.pkl')

# %% [markdown]
# - 이전 과정에서 저장한 파일을 읽어와 new_test, new_train 데이터프레임을 만듭니다.
#     - path + 'new_test.csv' → new_test
#     - path + 'new_train.csv' → new_train

# %%
# 파일 불러오기
new_test = pd.read_csv(path + 'new_test.csv')
new_train = pd.read_csv(path + 'new_train.csv')

# %%
# 기존 훈련 데이터 불러오기
original_df = pd.read_csv(path + 'data.csv')
print(original_df.shape)
# Out:
# (19278, 23)

# %%
new_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         850 non-null    int64
#  1   ID                                 850 non-null    int64
#  2   Gender                             850 non-null    object
#  3   Customer Type                      850 non-null    object
#  4   Age                                817 non-null    float64
#  5   Type of Travel                     850 non-null    object
#  6   Class                              850 non-null    object
#  7   Flight Distance                    850 non-null    int64
#  8   Inflight wifi service              830 non-null    float64
#  9   Departure/Arrival time convenient  850 non-null    int64
#  10  Ease of Online booking             850 non-null    int64
#  11  Gate location                      850 non-null    int64
#  12  Food and drink                     836 non-null    float64
#  13  Online boarding                    850 non-null    int64
#  14  Seat comfort                       823 non-null    float64
#  15  Inflight entertainment             850 non-null    int64
#  16  On-board service                   850 non-null    int64
#  17  Leg room service                   850 non-null    int64
#  18  Baggage handling                   850 non-null    int64
#  19  Checkin service                    850 non-null    int64
#  20  Inflight service                   850 non-null    int64
#  21  Cleanliness                        850 non-null    int64
#  22  Departure Delay in Minutes         850 non-null    int64
#  23  Arrival Delay in Minutes           847 non-null    float64
#  24  Satisfaction                       850 non-null    object
# dtypes: float64(5), int64(15), object(5)
# memory usage: 166.1+ KB

# %%
new_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         350 non-null    int64
#  1   ID                                 350 non-null    int64
#  2   Gender                             350 non-null    object
#  3   Customer Type                      350 non-null    object
#  4   Age                                340 non-null    float64
#  5   Type of Travel                     350 non-null    object
#  6   Class                              350 non-null    object
#  7   Flight Distance                    350 non-null    int64
#  8   Inflight wifi service              335 non-null    float64
#  9   Departure/Arrival time convenient  350 non-null    int64
#  10  Ease of Online booking             350 non-null    int64
#  11  Gate location                      350 non-null    int64
#  12  Food and drink                     342 non-null    float64
#  13  Online boarding                    350 non-null    int64
#  14  Seat comfort                       346 non-null    float64
#  15  Inflight entertainment             350 non-null    int64
#  16  On-board service                   350 non-null    int64
#  17  Leg room service                   350 non-null    int64
#  18  Baggage handling                   350 non-null    int64
#  19  Checkin service                    350 non-null    int64
#  20  Inflight service                   350 non-null    int64
#  21  Cleanliness                        350 non-null    int64
#  22  Departure Delay in Minutes         350 non-null    int64
#  23  Arrival Delay in Minutes           350 non-null    float64
#  24  Satisfaction                       350 non-null    object
# dtypes: float64(5), int64(15), object(5)
# memory usage: 68.5+ KB

# %%
new_test['Satisfaction'].value_counts()
# Out:
# Satisfaction
# Neutral or Dissatisfied    191
# Satisfied                  159
# Name: count, dtype: int64

# %%
new_train['Satisfaction'].value_counts()
# Out:
# Satisfaction
# Neutral or Dissatisfied    463
# Satisfied                  387
# Name: count, dtype: int64

# %%
new_train.describe()
# Out:
#           Unnamed: 0             ID         Age  Flight Distance  \
# count     850.000000     850.000000  817.000000       850.000000
# mean    52186.782353   68038.528235   38.887393      1243.060000
# std     30002.047030   37653.069414   15.507890      1010.359805
# min       271.000000      66.000000    7.000000        83.000000
# 25%     26769.500000   36066.500000   27.000000       436.000000
# 50%     51662.000000   68474.500000   40.000000       901.000000
# 75%     78419.000000  103302.500000   50.000000      1945.250000
# max    103687.000000  129690.000000   85.000000      4963.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count             830.000000                         850.000000
# mean                2.742169                           3.044706
# std                 1.328369                           1.507852
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count              850.000000     850.000000      836.000000       850.000000
# mean                 2.772941       3.015294        3.206938         3.260000
# std                  1.380999       1.263234        1.339050         1.329887
# min                  0.000000       1.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#        Seat comfort  Inflight entertainment  On-board service  \
# count    823.000000              850.000000        850.000000
# mean       3.465371                3.360000          3.372941
# std        1.325752                1.351107          1.299079
# min        1.000000                1.000000          1.000000
# 25%        2.000000                2.000000          2.000000
# 50%        4.000000                4.000000          4.000000
# 75%        5.000000                4.000000          4.000000
# max        5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count        850.000000        850.000000       850.000000        850.000000
# mean           3.330588          3.629412         3.295294          3.611765
# std            1.322143          1.204753         1.274411          1.193762
# min            0.000000          1.000000         1.000000          1.000000
# 25%            2.000000          3.000000         2.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count   850.000000                  850.000000                847.000000
# mean      3.274118                   14.455294                 14.981110
# std       1.330591                   37.173911                 37.835117
# min       1.000000                    0.000000                  0.000000
# 25%       2.000000                    0.000000                  0.000000
# 50%       3.000000                    0.000000                  0.000000
# 75%       4.000000                   10.000000                 11.000000
# max       5.000000                  319.000000                317.000000

# %%
new_test.describe()
# Out:
#           Unnamed: 0             ID         Age  Flight Distance  \
# count     350.000000     350.000000  340.000000       350.000000
# mean    48425.068571   65152.657143   39.658824      1208.000000
# std     29544.205709   37229.827120   15.664667       997.817797
# min       605.000000     421.000000    7.000000        67.000000
# 25%     23269.000000   33102.250000   26.000000       431.750000
# 50%     46005.500000   63395.000000   40.500000       877.000000
# 75%     73979.750000   99287.750000   52.000000      1711.000000
# max    103826.000000  129803.000000   80.000000      4963.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count             335.000000                         350.000000
# mean                2.650746                           3.125714
# std                 1.360408                           1.470306
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count              350.000000     350.000000      342.000000       350.000000
# mean                 2.711429       3.034286        3.251462         3.177143
# std                  1.414066       1.248023        1.309087         1.405084
# min                  0.000000       1.000000        1.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#        Seat comfort  Inflight entertainment  On-board service  \
# count    346.000000              350.000000        350.000000
# mean       3.473988                3.414286          3.434286
# std        1.319053                1.340282          1.332843
# min        1.000000                1.000000          1.000000
# 25%        2.250000                2.000000          2.000000
# 50%        4.000000                4.000000          4.000000
# 75%        5.000000                5.000000          5.000000
# max        5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count        350.000000        350.000000       350.000000        350.000000
# mean           3.348571          3.634286         3.428571          3.614286
# std            1.351508          1.183928         1.217958          1.217034
# min            0.000000          1.000000         1.000000          1.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         4.000000          4.000000
# 75%            5.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count   350.000000                  350.000000                350.000000
# mean      3.385714                   15.157143                 14.882857
# std       1.296821                   36.684138                 37.421099
# min       1.000000                    0.000000                  0.000000
# 25%       2.000000                    0.000000                  0.000000
# 50%       3.500000                    0.000000                  0.000000
# 75%       4.000000                   11.000000                  9.000000
# max       5.000000                  274.000000                310.000000

# %%
new_train.isnull().sum()
# Out:
# Unnamed: 0                            0
# ID                                    0
# Gender                                0
# Customer Type                         0
# Age                                  33
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                20
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                       14
# Online boarding                       0
# Seat comfort                         27
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes              3
# Satisfaction                          0
# dtype: int64

# %%
new_test.isnull().sum()
# Out:
# Unnamed: 0                            0
# ID                                    0
# Gender                                0
# Customer Type                         0
# Age                                  10
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                15
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        8
# Online boarding                       0
# Seat comfort                          4
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes              0
# Satisfaction                          0
# dtype: int64

# %% [markdown]
# ## **2. 미션 8: 전처리 파이프라인 만들기**
#
# - 다음 과정을 일괄 처리한 후 x, y를 반환하는 함수를 만듭니다.
#     - 결측치 처리
#     - Target 값 0/1로 변경
#     - 불필요한 변수 제거
#     - 라벨 인코딩
#     - 가변수화
#     - x, y 분리
#     - x 스케일링 등
# - 함수 이름은 **build_model_input** 로 지정합니다.
# - 다음과 같이 사용할 수 있어야 합니다.
#     - 예1) x_val, y_val = build_model_input(new_test)
#     - 예2) x_trian, y_train = build_model_input(new_train)
#
# ## **새로운 학습 전략:**
#
# ### **방법 1: 원본 데이터 + 새로운 학습/평가 데이터를 포함한 전체 데이터로 학습**
# - `original_df` (raw), `new_train`, `new_test` 를 합쳐서 `x_combined_train`, `y_combined_train`을 생성합니다.
# - `base_model`을 초기화하여 이 데이터로 다시 학습(`model1`).
#
# ### **방법 2: 새로운 학습 데이터(`new_train`)만으로 추가 학습**
# - `new_train` 데이터만으로 `x_train_new_data`, `y_train_new_data`를 생성합니다.
# - 기존 `base_model`에 `new_train` 데이터만으로 추가 학습(`model2`) 또는 미세 조정(`model3`).

# %%
# 결측치 처리전 확인
# Age
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Age'], kde=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Age'], kde=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# 결측치 처리전 확인
# Inflight wifi service
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Inflight wifi service'], kde=True)
plt.xlabel('Inflight wifi service')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Inflight wifi service'], kde=True)
plt.xlabel('Inflight wifi service')
plt.ylabel('Count')
plt.show()

# %%
# 결측치 처리전 확인
# Food and drink
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Food and drink'], kde=True)
plt.xlabel('Food and drink')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Food and drink'], kde=True)
plt.xlabel('Food and drink')
plt.ylabel('Count')
plt.show()

# %%
# 결측치 처리전 확인
# Seat comfort
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Seat comfort'], kde=True)
plt.xlabel('Seat comfort')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Seat comfort'], kde=True)
plt.xlabel('Seat comfort')
plt.ylabel('Count')
plt.show()

# %%
# 결측치 처리전 확인
# Arrival Delay in Minutes
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Arrival Delay in Minutes'], kde=True)
plt.xlabel('Arrival Delay in Minutes')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Arrival Delay in Minutes'], kde=True)
plt.xlabel('Arrival Delay in Minutes')
plt.ylabel('Count')
plt.show()

# %%
def build_model_input(data):
    df = data.copy()

    # 1. 결측치 처리 (수치형/점수형 변수)
    impute_cols = ['Age', 'Inflight wifi service', 'Food and drink', 'Seat comfort', 'Arrival Delay in Minutes']
    for col in impute_cols:
        if col in df.columns:
            df[col] = df[col].fillna(df[col].median())

    # 2. Target 값 변경 및 결측치 행 제거
    y = None
    if 'Satisfaction' in df.columns:
        df['Satisfaction'] = df['Satisfaction'].str.lower()
        df['Satisfaction'] = df['Satisfaction'].map({'satisfied': 1, 'neutral or dissatisfied': 0})

        df = df.dropna(subset=['Satisfaction'])

        if df.empty:
            return pd.DataFrame(), np.array([])

        y = df['Satisfaction'].values
        df.drop(columns=['Satisfaction'], inplace=True)

    # 3. 불필요한 변수 제거
    df.drop(columns=['Unnamed: 0', 'ID'], inplace=True, errors='ignore')

    # 4. 라벨 인코딩
    if 'Gender' in df.columns:
        df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
    if 'Customer Type' in df.columns:
        df['Customer Type'] = df['Customer Type'].str.lower().map({'loyal customer': 1, 'disloyal customer': 0})

    # 5. 가변수화
    cat_cols = ['Type of Travel', 'Class', 'Inflight wifi service', 'Departure/Arrival time convenient',
                'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding',
                'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service',
                'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness']
    existing_cat_cols = [c for c in cat_cols if c in df.columns]
    df = pd.get_dummies(df, columns=existing_cat_cols)

    # 6. 스케일러 피처와 일치시키기
    try:
        cols = scaler.feature_names_in_.tolist()
        for col in cols:
            if col not in df.columns:
                df[col] = 0
        x = df[cols]
    except AttributeError:
        x = df

    if x.empty:
        return pd.DataFrame(), np.array([])

    # 7. 스케일링 적용
    x_scaled = scaler.transform(x)
    x_final = pd.DataFrame(x_scaled, columns=x.columns)

    return x_final, y

# %% [markdown]
# - 점검: 다음 구문이 잘 수행되어 x_val, y_val이 분리되어야 합니다.

# %%
# x_val, y_val 나누기
x_val, y_val = build_model_input(new_test)

# 확인
print('x_val shape:', x_val.shape)
print('y_val shape:', y_val.shape)
# Out:
# x_val shape: (350, 78)
# y_val shape: (350,)

# %% [markdown]
# ## **3. 미션 9: 기본 모델로 예측 및 평가**

# %% [markdown]
# ### (1) 데이터 전처리
#
# - new_test 데이터프레임을 x_val, y_val로 분리합니다.

# %%
# 방법 2를 위한 데이터 준비 (new_train만 사용)
x_train_new_data, y_train_new_data = build_model_input(new_train)

# 검증 데이터는 모든 모델에서 동일하게 사용
x_val, y_val = build_model_input(new_test)

print('x_train_new_data shape:', x_train_new_data.shape, 'y_train_new_data shape:', y_train_new_data.shape)
print('x_val shape:', x_val.shape, 'y_val shape:', y_val.shape)
# Out:
# x_train_new_data shape: (850, 78) y_train_new_data shape: (850,)
# x_val shape: (350, 78) y_val shape: (350,)

# %% [markdown]
# ### 전처리 후 결측치 및 데이터 타입 확인

# %%
# x_train 결측치 확인
print(x_train_new_data.isnull().sum().sum())

# x_val 결측치 확인
print(x_val.isnull().sum().sum())
# Out:
# 0
# 0

# %%
x_train_new_data.info() # object 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 78 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               850 non-null    float64
#  1   Customer Type                        850 non-null    float64
#  2   Age                                  850 non-null    float64
#  3   Type of Travel                       850 non-null    float64
#  4   Class                                850 non-null    float64
#  5   Flight Distance                      850 non-null    float64
#  6   Departure Delay in Minutes           850 non-null    float64
#  7   Arrival Delay in Minutes             850 non-null    float64
#  8   Inflight wifi service_1              850 non-null    float64
#  9   Inflight wifi service_2              850 non-null    float64
#  10  Inflight wifi service_3              850 non-null    float64
#  11  Inflight wifi service_4              850 non-null    float64
#  12  Inflight wifi service_5              850 non-null    float64
#  13  Departure/Arrival time convenient_1  850 non-null    float64
#  14  Departure/Arrival time convenient_2  850 non-null    float64
#  15  Departure/Arrival time convenient_3  850 non-null    float64
#  16  Departure/Arrival time convenient_4  850 non-null    float64
#  17  Departure/Arrival time convenient_5  850 non-null    float64
#  18  Ease of Online booking_1             850 non-null    float64
#  19  Ease of Online booking_2             850 non-null    float64
#  20  Ease of Online booking_3             850 non-null    float64
#  21  Ease of Online booking_4             850 non-null    float64
#  22  Ease of Online booking_5             850 non-null    float64
#  23  Gate location_1                      850 non-null    float64
#  24  Gate location_2                      850 non-null    float64
#  25  Gate location_3                      850 non-null    float64
#  26  Gate location_4                      850 non-null    float64
#  27  Gate location_5                      850 non-null    float64
#  28  Food and drink_1                     850 non-null    float64
#  29  Food and drink_2                     850 non-null    float64
#  30  Food and drink_3                     850 non-null    float64
#  31  Food and drink_4                     850 non-null    float64
#  32  Food and drink_5                     850 non-null    float64
#  33  Online boarding_1                    850 non-null    float64
#  34  Online boarding_2                    850 non-null    float64
#  35  Online boarding_3                    850 non-null    float64
#  36  Online boarding_4                    850 non-null    float64
#  37  Online boarding_5                    850 non-null    float64
#  38  Seat comfort_1                       850 non-null    float64
#  39  Seat comfort_2                       850 non-null    float64
#  40  Seat comfort_3                       850 non-null    float64
#  41  Seat comfort_4                       850 non-null    float64
#  42  Seat comfort_5                       850 non-null    float64
#  43  Inflight entertainment_1             850 non-null    float64
#  44  Inflight entertainment_2             850 non-null    float64
#  45  Inflight entertainment_3             850 non-null    float64
#  46  Inflight entertainment_4             850 non-null    float64
#  47  Inflight entertainment_5             850 non-null    float64
#  48  On-board service_1                   850 non-null    float64
#  49  On-board service_2                   850 non-null    float64
#  50  On-board service_3                   850 non-null    float64
#  51  On-board service_4                   850 non-null    float64
#  52  On-board service_5                   850 non-null    float64
#  53  Leg room service_1                   850 non-null    float64
#  54  Leg room service_2                   850 non-null    float64
#  55  Leg room service_3                   850 non-null    float64
#  56  Leg room service_4                   850 non-null    float64
#  57  Leg room service_5                   850 non-null    float64
#  58  Baggage handling_1                   850 non-null    float64
#  59  Baggage handling_2                   850 non-null    float64
#  60  Baggage handling_3                   850 non-null    float64
#  61  Baggage handling_4                   850 non-null    float64
#  62  Baggage handling_5                   850 non-null    float64
#  63  Checkin service_1                    850 non-null    float64
#  64  Checkin service_2                    850 non-null    float64
#  65  Checkin service_3                    850 non-null    float64
#  66  Checkin service_4                    850 non-null    float64
#  67  Checkin service_5                    850 non-null    float64
#  68  Inflight service_1                   850 non-null    float64
#  69  Inflight service_2                   850 non-null    float64
#  70  Inflight service_3                   850 non-null    float64
#  71  Inflight service_4                   850 non-null    float64
#  72  Inflight service_5                   850 non-null    float64
#  73  Cleanliness_1                        850 non-null    float64
#  74  Cleanliness_2                        850 non-null    float64
#  75  Cleanliness_3                        850 non-null    float64
#  76  Cleanliness_4                        850 non-null    float64
#  77  Cleanliness_5                        850 non-null    float64
# dtypes: float64(78)
# memory usage: 518.1 KB

# %%
x_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 78 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               350 non-null    float64
#  1   Customer Type                        350 non-null    float64
#  2   Age                                  350 non-null    float64
#  3   Type of Travel                       350 non-null    float64
#  4   Class                                350 non-null    float64
#  5   Flight Distance                      350 non-null    float64
#  6   Departure Delay in Minutes           350 non-null    float64
#  7   Arrival Delay in Minutes             350 non-null    float64
#  8   Inflight wifi service_1              350 non-null    float64
#  9   Inflight wifi service_2              350 non-null    float64
#  10  Inflight wifi service_3              350 non-null    float64
#  11  Inflight wifi service_4              350 non-null    float64
#  12  Inflight wifi service_5              350 non-null    float64
#  13  Departure/Arrival time convenient_1  350 non-null    float64
#  14  Departure/Arrival time convenient_2  350 non-null    float64
#  15  Departure/Arrival time convenient_3  350 non-null    float64
#  16  Departure/Arrival time convenient_4  350 non-null    float64
#  17  Departure/Arrival time convenient_5  350 non-null    float64
#  18  Ease of Online booking_1             350 non-null    float64
#  19  Ease of Online booking_2             350 non-null    float64
#  20  Ease of Online booking_3             350 non-null    float64
#  21  Ease of Online booking_4             350 non-null    float64
#  22  Ease of Online booking_5             350 non-null    float64
#  23  Gate location_1                      350 non-null    float64
#  24  Gate location_2                      350 non-null    float64
#  25  Gate location_3                      350 non-null    float64
#  26  Gate location_4                      350 non-null    float64
#  27  Gate location_5                      350 non-null    float64
#  28  Food and drink_1                     350 non-null    float64
#  29  Food and drink_2                     350 non-null    float64
#  30  Food and drink_3                     350 non-null    float64
#  31  Food and drink_4                     350 non-null    float64
#  32  Food and drink_5                     350 non-null    float64
#  33  Online boarding_1                    350 non-null    float64
#  34  Online boarding_2                    350 non-null    float64
#  35  Online boarding_3                    350 non-null    float64
#  36  Online boarding_4                    350 non-null    float64
#  37  Online boarding_5                    350 non-null    float64
#  38  Seat comfort_1                       350 non-null    float64
#  39  Seat comfort_2                       350 non-null    float64
#  40  Seat comfort_3                       350 non-null    float64
#  41  Seat comfort_4                       350 non-null    float64
#  42  Seat comfort_5                       350 non-null    float64
#  43  Inflight entertainment_1             350 non-null    float64
#  44  Inflight entertainment_2             350 non-null    float64
#  45  Inflight entertainment_3             350 non-null    float64
#  46  Inflight entertainment_4             350 non-null    float64
#  47  Inflight entertainment_5             350 non-null    float64
#  48  On-board service_1                   350 non-null    float64
#  49  On-board service_2                   350 non-null    float64
#  50  On-board service_3                   350 non-null    float64
#  51  On-board service_4                   350 non-null    float64
#  52  On-board service_5                   350 non-null    float64
#  53  Leg room service_1                   350 non-null    float64
#  54  Leg room service_2                   350 non-null    float64
#  55  Leg room service_3                   350 non-null    float64
#  56  Leg room service_4                   350 non-null    float64
#  57  Leg room service_5                   350 non-null    float64
#  58  Baggage handling_1                   350 non-null    float64
#  59  Baggage handling_2                   350 non-null    float64
#  60  Baggage handling_3                   350 non-null    float64
#  61  Baggage handling_4                   350 non-null    float64
#  62  Baggage handling_5                   350 non-null    float64
#  63  Checkin service_1                    350 non-null    float64
#  64  Checkin service_2                    350 non-null    float64
#  65  Checkin service_3                    350 non-null    float64
#  66  Checkin service_4                    350 non-null    float64
#  67  Checkin service_5                    350 non-null    float64
#  68  Inflight service_1                   350 non-null    float64
#  69  Inflight service_2                   350 non-null    float64
#  70  Inflight service_3                   350 non-null    float64
#  71  Inflight service_4                   350 non-null    float64
#  72  Inflight service_5                   350 non-null    float64
#  73  Cleanliness_1                        350 non-null    float64
#  74  Cleanliness_2                        350 non-null    float64
#  75  Cleanliness_3                        350 non-null    float64
#  76  Cleanliness_4                        350 non-null    float64
#  77  Cleanliness_5                        350 non-null    float64
# dtypes: float64(78)
# memory usage: 213.4 KB

# %% [markdown]
# ### (2) 예측 및 평가
#
# - 새로운 데이터에 대한 예측과 평가를 수행합니다.

# %% [markdown]
# ## **4. 미션 10: 모델 추가 학습**

# %% [markdown]
# ### (1) 학습용 데이터 준비
#
# - **방법 1:** `original_df`, `new_train`, `new_test`를 합쳐 `x_combined_train`, `y_combined_train`을 준비합니다.
# - **방법 2:** `new_train` 데이터프레임을 `x_train_new_data`, `y_train_new_data`로 분리합니다. (위에서 이미 수행됨)

# %%
# 방법 1: original_df, new_train, new_test를 합친 데이터 준비
# 주의: original_df는 build_model_input 함수가 예상하는 '원시' 상태여야 합니다.
# 기존 original_df가 이미 전처리된 상태일 수 있으므로, 다시 로드하여 raw 상태로 사용합니다.
df_raw_original = pd.read_csv(path + 'data.csv')

# ID 컬럼을 제외한 모든 컬럼에 대해 결합 (Unnamed: 0은 build_model_input에서 처리됨)
# new_train과 new_test는 이미 로드된 상태이므로 그대로 사용
combined_raw_df = pd.concat([df_raw_original, new_train, new_test], ignore_index=True)

x_combined_train, y_combined_train = build_model_input(combined_raw_df)

# Combined data에 대한 클래스 가중치 계산
class_weights_combined = class_weight.compute_class_weight('balanced', classes=np.unique(y_combined_train), y=y_combined_train)
class_weight_dict_combined = dict(enumerate(class_weights_combined))

print('x_combined_train shape:', x_combined_train.shape)
print('y_combined_train shape:', y_combined_train.shape)
print('Class Weight Dictionary (Combined Data):', class_weight_dict_combined)

# 방법 2: new_train 데이터에 대한 클래스 가중치 계산 (model2, model3용)
class_weights_new_data = class_weight.compute_class_weight('balanced', classes=np.unique(y_train_new_data), y=y_train_new_data)
class_weight_dict_new_data = dict(enumerate(class_weights_new_data))

print('\nx_train_new_data shape:', x_train_new_data.shape)
print('y_train_new_data shape:', y_train_new_data.shape)
print('Class Weight Dictionary (New Data Only):', class_weight_dict_new_data)
# Out:
# x_combined_train shape: (1200, 78)
# y_combined_train shape: (1200,)
# Class Weight Dictionary (Combined Data): {0: np.float64(0.9174311926605505), 1: np.float64(1.098901098901099)}
#
# x_train_new_data shape: (850, 78)
# y_train_new_data shape: (850,)
# Class Weight Dictionary (New Data Only): {0: np.float64(0.91792656587473), 1: np.float64(1.0981912144702843)}

# %% [markdown]
# ### (2) 방법 1: 모델 초기화
#
# - 이전에 만들었던 성능이 좋았던 모델과 같은 모델을 만들어 학습 후 성능을 확인합니다.

# %%
# 방법 1: 모델 초기화 및 전체 데이터로 학습
clear_session()
nf = x_combined_train.shape[1] # 전체 데이터셋의 피처 수

model1 = Sequential([
    Input(shape=(nf, )),
    Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.4),
    Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.3),
    Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.4),
    Dense(4, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model1.summary()

# 학습 방법을 설정하고 학습을 수행합니다.
model1.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history1 = model1.fit(x_combined_train, y_combined_train, epochs=300, batch_size=32, validation_data=(x_val, y_val), callbacks=[es], verbose=1, class_weight=class_weight_dict_combined)

# 학습 곡선 확인
dl_history_plot(history1.history)

# 검증 데이터 평가
y_pred1 = model1.predict(x_val)
y_pred1 = (y_pred1 > 0.5).astype(int)

print(classification_report(y_val, y_pred1))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         2,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,233 (12.63 KB)
#  Trainable params: 3,233 (12.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 111ms/step - accuracy: 0.5042 - loss: 0.7809 - val_accuracy: 0.5571 - val_loss: 0.7709
# Epoch 2/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4950 - loss: 0.7741 - val_accuracy: 0.5571 - val_loss: 0.7692
# Epoch 3/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4875 - loss: 0.7797 - val_accuracy: 0.5600 - val_loss: 0.7677
# Epoch 4/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5067 - loss: 0.7762 - val_accuracy: 0.5571 - val_loss: 0.7663
# Epoch 5/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4850 - loss: 0.7750 - val_accuracy: 0.5629 - val_loss: 0.7651
# Epoch 6/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4983 - loss: 0.7705 - val_accuracy: 0.5714 - val_loss: 0.7641
# Epoch 7/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5025 - loss: 0.7688 - val_accuracy: 0.5857 - val_loss: 0.7632
# Epoch 8/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5067 - loss: 0.7652 - val_accuracy: 0.5943 - val_loss: 0.7620
# Epoch 9/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4983 - loss: 0.7718 - val_accuracy: 0.6000 - val_loss: 0.7611
# Epoch 10/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4892 - loss: 0.7698 - val_accuracy: 0.6000 - val_loss: 0.7604
# Epoch 11/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5108 - loss: 0.7672 - val_accuracy: 0.6171 - val_loss: 0.7594
# Epoch 12/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4842 - loss: 0.7698 - val_accuracy: 0.6143 - val_loss: 0.7584
# Epoch 13/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5108 - loss: 0.7654 - val_accuracy: 0.6257 - val_loss: 0.7571
# Epoch 14/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5342 - loss: 0.7566 - val_accuracy: 0.6314 - val_loss: 0.7560
# Epoch 15/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5017 - loss: 0.7633 - val_accuracy: 0.6343 - val_loss: 0.7548
# Epoch 16/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4883 - loss: 0.7653 - val_accuracy: 0.6457 - val_loss: 0.7535
# Epoch 17/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5067 - loss: 0.7592 - val_accuracy: 0.6429 - val_loss: 0.7525
# Epoch 18/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5208 - loss: 0.7580 - val_accuracy: 0.6571 - val_loss: 0.7511
# Epoch 19/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5275 - loss: 0.7512 - val_accuracy: 0.6686 - val_loss: 0.7496
# Epoch 20/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5058 - loss: 0.7583 - val_accuracy: 0.6829 - val_loss: 0.7483
# Epoch 21/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5192 - loss: 0.7544 - val_accuracy: 0.6800 - val_loss: 0.7471
# Epoch 22/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5217 - loss: 0.7504 - val_accuracy: 0.6829 - val_loss: 0.7457
# Epoch 23/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5375 - loss: 0.7503 - val_accuracy: 0.7029 - val_loss: 0.7435
# Epoch 24/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5125 - loss: 0.7501 - val_accuracy: 0.7000 - val_loss: 0.7421
# Epoch 25/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5433 - loss: 0.7458 - val_accuracy: 0.7114 - val_loss: 0.7404
# Epoch 26/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5300 - loss: 0.7461 - val_accuracy: 0.7057 - val_loss: 0.7382
# Epoch 27/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5325 - loss: 0.7464 - val_accuracy: 0.7086 - val_loss: 0.7358
# Epoch 28/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5542 - loss: 0.7444 - val_accuracy: 0.7171 - val_loss: 0.7338
# Epoch 29/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5367 - loss: 0.7440 - val_accuracy: 0.7086 - val_loss: 0.7313
# Epoch 30/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5525 - loss: 0.7376 - val_accuracy: 0.7114 - val_loss: 0.7285
# Epoch 31/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5442 - loss: 0.7399 - val_accuracy: 0.7200 - val_loss: 0.7263
# Epoch 32/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5358 - loss: 0.7432 - val_accuracy: 0.7229 - val_loss: 0.7245
# Epoch 33/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5542 - loss: 0.7333 - val_accuracy: 0.7314 - val_loss: 0.7223
# Epoch 34/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5450 - loss: 0.7339 - val_accuracy: 0.7257 - val_loss: 0.7193
# Epoch 35/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5567 - loss: 0.7295 - val_accuracy: 0.7314 - val_loss: 0.7162
# Epoch 36/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5742 - loss: 0.7272 - val_accuracy: 0.7429 - val_loss: 0.7128
# Epoch 37/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5692 - loss: 0.7305 - val_accuracy: 0.7400 - val_loss: 0.7094
# Epoch 38/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5617 - loss: 0.7312 - val_accuracy: 0.7514 - val_loss: 0.7063
# Epoch 39/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5592 - loss: 0.7291 - val_accuracy: 0.7629 - val_loss: 0.7048
# Epoch 40/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5767 - loss: 0.7172 - val_accuracy: 0.7686 - val_loss: 0.7008
# Epoch 41/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5642 - loss: 0.7238 - val_accuracy: 0.7714 - val_loss: 0.6975
# Epoch 42/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5825 - loss: 0.7202 - val_accuracy: 0.7714 - val_loss: 0.6946
# Epoch 43/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5900 - loss: 0.7140 - val_accuracy: 0.7714 - val_loss: 0.6915
# Epoch 44/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5917 - loss: 0.7128 - val_accuracy: 0.7686 - val_loss: 0.6872
# Epoch 45/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5883 - loss: 0.7076 - val_accuracy: 0.7771 - val_loss: 0.6826
# Epoch 46/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5983 - loss: 0.7088 - val_accuracy: 0.7771 - val_loss: 0.6794
# Epoch 47/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6008 - loss: 0.6993 - val_accuracy: 0.7886 - val_loss: 0.6752
# Epoch 48/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6242 - loss: 0.6990 - val_accuracy: 0.7971 - val_loss: 0.6706
# Epoch 49/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5892 - loss: 0.7099 - val_accuracy: 0.7943 - val_loss: 0.6678
# Epoch 50/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5917 - loss: 0.7044 - val_accuracy: 0.7971 - val_loss: 0.6643
# Epoch 51/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6192 - loss: 0.6945 - val_accuracy: 0.8029 - val_loss: 0.6602
# Epoch 52/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6017 - loss: 0.7027 - val_accuracy: 0.8029 - val_loss: 0.6563
# Epoch 53/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6008 - loss: 0.6872 - val_accuracy: 0.8114 - val_loss: 0.6524
# Epoch 54/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6117 - loss: 0.6831 - val_accuracy: 0.8171 - val_loss: 0.6479
# Epoch 55/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6192 - loss: 0.6860 - val_accuracy: 0.8200 - val_loss: 0.6429
# Epoch 56/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6083 - loss: 0.6808 - val_accuracy: 0.8200 - val_loss: 0.6386
# Epoch 57/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6300 - loss: 0.6813 - val_accuracy: 0.8200 - val_loss: 0.6351
# Epoch 58/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6217 - loss: 0.6850 - val_accuracy: 0.8200 - val_loss: 0.6316
# Epoch 59/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6533 - loss: 0.6687 - val_accuracy: 0.8257 - val_loss: 0.6261
# Epoch 60/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6325 - loss: 0.6786 - val_accuracy: 0.8200 - val_loss: 0.6231
# Epoch 61/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6150 - loss: 0.6775 - val_accuracy: 0.8200 - val_loss: 0.6221
# Epoch 62/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6433 - loss: 0.6621 - val_accuracy: 0.8229 - val_loss: 0.6173
# Epoch 63/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6108 - loss: 0.6875 - val_accuracy: 0.8286 - val_loss: 0.6145
# Epoch 64/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6525 - loss: 0.6591 - val_accuracy: 0.8314 - val_loss: 0.6114
# Epoch 65/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6442 - loss: 0.6570 - val_accuracy: 0.8286 - val_loss: 0.6087
# Epoch 66/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6525 - loss: 0.6622 - val_accuracy: 0.8286 - val_loss: 0.6046
# Epoch 67/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6617 - loss: 0.6609 - val_accuracy: 0.8314 - val_loss: 0.6010
# Epoch 68/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6675 - loss: 0.6413 - val_accuracy: 0.8371 - val_loss: 0.5966
# Epoch 69/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6600 - loss: 0.6458 - val_accuracy: 0.8343 - val_loss: 0.5938
# Epoch 70/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6617 - loss: 0.6392 - val_accuracy: 0.8343 - val_loss: 0.5902
# Epoch 71/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6383 - loss: 0.6549 - val_accuracy: 0.8314 - val_loss: 0.5876
# Epoch 72/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6525 - loss: 0.6579 - val_accuracy: 0.8286 - val_loss: 0.5846
# Epoch 73/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6467 - loss: 0.6509 - val_accuracy: 0.8257 - val_loss: 0.5836
# Epoch 74/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6433 - loss: 0.6473 - val_accuracy: 0.8229 - val_loss: 0.5819
# Epoch 75/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6342 - loss: 0.6690 - val_accuracy: 0.8314 - val_loss: 0.5796
# Epoch 76/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6625 - loss: 0.6423 - val_accuracy: 0.8286 - val_loss: 0.5769
# Epoch 77/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6617 - loss: 0.6302 - val_accuracy: 0.8343 - val_loss: 0.5726
# Epoch 78/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6900 - loss: 0.6153 - val_accuracy: 0.8457 - val_loss: 0.5665
# Epoch 79/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6625 - loss: 0.6286 - val_accuracy: 0.8457 - val_loss: 0.5628
# Epoch 80/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6717 - loss: 0.6340 - val_accuracy: 0.8343 - val_loss: 0.5613
# Epoch 81/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6767 - loss: 0.6093 - val_accuracy: 0.8486 - val_loss: 0.5566
# Epoch 82/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6592 - loss: 0.6220 - val_accuracy: 0.8371 - val_loss: 0.5537
# Epoch 83/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6750 - loss: 0.6076 - val_accuracy: 0.8371 - val_loss: 0.5490
# Epoch 84/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6808 - loss: 0.6151 - val_accuracy: 0.8286 - val_loss: 0.5462
# Epoch 85/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6633 - loss: 0.6089 - val_accuracy: 0.8286 - val_loss: 0.5429
# Epoch 86/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6800 - loss: 0.6238 - val_accuracy: 0.8286 - val_loss: 0.5421
# Epoch 87/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6517 - loss: 0.6206 - val_accuracy: 0.8286 - val_loss: 0.5389
# Epoch 88/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6717 - loss: 0.6241 - val_accuracy: 0.8286 - val_loss: 0.5377
# Epoch 89/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6958 - loss: 0.6116 - val_accuracy: 0.8343 - val_loss: 0.5358
# Epoch 90/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6900 - loss: 0.6037 - val_accuracy: 0.8343 - val_loss: 0.5333
# Epoch 91/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6825 - loss: 0.6147 - val_accuracy: 0.8371 - val_loss: 0.5316
# Epoch 92/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6800 - loss: 0.6197 - val_accuracy: 0.8343 - val_loss: 0.5313
# Epoch 93/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6842 - loss: 0.6078 - val_accuracy: 0.8400 - val_loss: 0.5284
# Epoch 94/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6967 - loss: 0.5939 - val_accuracy: 0.8371 - val_loss: 0.5262
# Epoch 95/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6867 - loss: 0.5881 - val_accuracy: 0.8429 - val_loss: 0.5214
# Epoch 96/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6717 - loss: 0.5965 - val_accuracy: 0.8429 - val_loss: 0.5191
# Epoch 97/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7008 - loss: 0.5901 - val_accuracy: 0.8429 - val_loss: 0.5164
# Epoch 98/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6933 - loss: 0.5943 - val_accuracy: 0.8400 - val_loss: 0.5152
# Epoch 99/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6608 - loss: 0.6230 - val_accuracy: 0.8371 - val_loss: 0.5138
# Epoch 100/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6900 - loss: 0.5824 - val_accuracy: 0.8400 - val_loss: 0.5128
# Epoch 101/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6833 - loss: 0.5919 - val_accuracy: 0.8400 - val_loss: 0.5107
# Epoch 102/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6983 - loss: 0.5897 - val_accuracy: 0.8371 - val_loss: 0.5079
# Epoch 103/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6917 - loss: 0.5721 - val_accuracy: 0.8400 - val_loss: 0.5050
# Epoch 104/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6750 - loss: 0.5925 - val_accuracy: 0.8400 - val_loss: 0.5039
# Epoch 105/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7033 - loss: 0.5712 - val_accuracy: 0.8371 - val_loss: 0.4999
# Epoch 106/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7217 - loss: 0.5667 - val_accuracy: 0.8429 - val_loss: 0.4966
# Epoch 107/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6792 - loss: 0.5961 - val_accuracy: 0.8400 - val_loss: 0.4962
# Epoch 108/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6867 - loss: 0.5928 - val_accuracy: 0.8400 - val_loss: 0.4968
# Epoch 109/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7008 - loss: 0.5873 - val_accuracy: 0.8457 - val_loss: 0.4962
# Epoch 110/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6850 - loss: 0.5843 - val_accuracy: 0.8457 - val_loss: 0.4936
# Epoch 111/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7167 - loss: 0.5738 - val_accuracy: 0.8429 - val_loss: 0.4925
# Epoch 112/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7117 - loss: 0.5865 - val_accuracy: 0.8429 - val_loss: 0.4926
# Epoch 113/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6942 - loss: 0.5915 - val_accuracy: 0.8429 - val_loss: 0.4919
# Epoch 114/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7042 - loss: 0.5651 - val_accuracy: 0.8486 - val_loss: 0.4897
# Epoch 115/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7058 - loss: 0.5661 - val_accuracy: 0.8514 - val_loss: 0.4873
# Epoch 116/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7008 - loss: 0.5720 - val_accuracy: 0.8571 - val_loss: 0.4849
# Epoch 117/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7075 - loss: 0.5683 - val_accuracy: 0.8514 - val_loss: 0.4821
# Epoch 118/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7200 - loss: 0.5588 - val_accuracy: 0.8543 - val_loss: 0.4808
# Epoch 119/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7042 - loss: 0.5788 - val_accuracy: 0.8543 - val_loss: 0.4798
# Epoch 120/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7117 - loss: 0.5579 - val_accuracy: 0.8543 - val_loss: 0.4797
# Epoch 121/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7167 - loss: 0.5575 - val_accuracy: 0.8543 - val_loss: 0.4786
# Epoch 122/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7017 - loss: 0.5691 - val_accuracy: 0.8543 - val_loss: 0.4770
# Epoch 123/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7183 - loss: 0.5609 - val_accuracy: 0.8543 - val_loss: 0.4755
# Epoch 124/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7050 - loss: 0.5579 - val_accuracy: 0.8543 - val_loss: 0.4734
# Epoch 125/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7050 - loss: 0.5716 - val_accuracy: 0.8543 - val_loss: 0.4720
# Epoch 126/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7042 - loss: 0.5766 - val_accuracy: 0.8543 - val_loss: 0.4710
# Epoch 127/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7350 - loss: 0.5577 - val_accuracy: 0.8543 - val_loss: 0.4692
# Epoch 128/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7342 - loss: 0.5466 - val_accuracy: 0.8543 - val_loss: 0.4663
# Epoch 129/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7258 - loss: 0.5644 - val_accuracy: 0.8543 - val_loss: 0.4659
# Epoch 130/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7050 - loss: 0.5534 - val_accuracy: 0.8543 - val_loss: 0.4642
# Epoch 131/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7042 - loss: 0.5492 - val_accuracy: 0.8514 - val_loss: 0.4637
# Epoch 132/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7267 - loss: 0.5501 - val_accuracy: 0.8514 - val_loss: 0.4627
# Epoch 133/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7525 - loss: 0.5434 - val_accuracy: 0.8514 - val_loss: 0.4621
# Epoch 134/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7383 - loss: 0.5425 - val_accuracy: 0.8514 - val_loss: 0.4589
# Epoch 135/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7033 - loss: 0.5663 - val_accuracy: 0.8514 - val_loss: 0.4599
# Epoch 136/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7200 - loss: 0.5549 - val_accuracy: 0.8514 - val_loss: 0.4593
# Epoch 137/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7058 - loss: 0.5544 - val_accuracy: 0.8514 - val_loss: 0.4591
# Epoch 138/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7400 - loss: 0.5330 - val_accuracy: 0.8514 - val_loss: 0.4564
# Epoch 139/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7208 - loss: 0.5555 - val_accuracy: 0.8514 - val_loss: 0.4560
# Epoch 140/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7083 - loss: 0.5584 - val_accuracy: 0.8543 - val_loss: 0.4564
# Epoch 141/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7225 - loss: 0.5354 - val_accuracy: 0.8571 - val_loss: 0.4547
# Epoch 142/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7142 - loss: 0.5437 - val_accuracy: 0.8571 - val_loss: 0.4546
# Epoch 143/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7183 - loss: 0.5466 - val_accuracy: 0.8571 - val_loss: 0.4529
# Epoch 144/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7400 - loss: 0.5319 - val_accuracy: 0.8571 - val_loss: 0.4516
# Epoch 145/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7467 - loss: 0.5322 - val_accuracy: 0.8543 - val_loss: 0.4488
# Epoch 146/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7258 - loss: 0.5374 - val_accuracy: 0.8600 - val_loss: 0.4485
# Epoch 147/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7350 - loss: 0.5429 - val_accuracy: 0.8571 - val_loss: 0.4457
# Epoch 148/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7517 - loss: 0.5343 - val_accuracy: 0.8600 - val_loss: 0.4431
# Epoch 149/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7583 - loss: 0.5182 - val_accuracy: 0.8571 - val_loss: 0.4393
# Epoch 150/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7267 - loss: 0.5569 - val_accuracy: 0.8571 - val_loss: 0.4386
# Epoch 151/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7217 - loss: 0.5528 - val_accuracy: 0.8600 - val_loss: 0.4393
# Epoch 152/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7483 - loss: 0.5259 - val_accuracy: 0.8571 - val_loss: 0.4381
# Epoch 153/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7342 - loss: 0.5298 - val_accuracy: 0.8571 - val_loss: 0.4366
# Epoch 154/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7692 - loss: 0.5199 - val_accuracy: 0.8600 - val_loss: 0.4345
# Epoch 155/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7583 - loss: 0.5335 - val_accuracy: 0.8571 - val_loss: 0.4324
# Epoch 156/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7483 - loss: 0.5205 - val_accuracy: 0.8571 - val_loss: 0.4299
# Epoch 157/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7508 - loss: 0.5210 - val_accuracy: 0.8571 - val_loss: 0.4287
# Epoch 158/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7525 - loss: 0.5327 - val_accuracy: 0.8571 - val_loss: 0.4283
# Epoch 159/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7675 - loss: 0.5215 - val_accuracy: 0.8600 - val_loss: 0.4257
# Epoch 160/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7550 - loss: 0.5380 - val_accuracy: 0.8600 - val_loss: 0.4238
# Epoch 161/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7292 - loss: 0.5288 - val_accuracy: 0.8600 - val_loss: 0.4214
# Epoch 162/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7683 - loss: 0.5073 - val_accuracy: 0.8629 - val_loss: 0.4194
# Epoch 163/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7733 - loss: 0.5009 - val_accuracy: 0.8629 - val_loss: 0.4174
# Epoch 164/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7617 - loss: 0.5298 - val_accuracy: 0.8629 - val_loss: 0.4168
# Epoch 165/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7692 - loss: 0.5147 - val_accuracy: 0.8629 - val_loss: 0.4160
# Epoch 166/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7700 - loss: 0.5020 - val_accuracy: 0.8629 - val_loss: 0.4139
# Epoch 167/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7442 - loss: 0.5191 - val_accuracy: 0.8629 - val_loss: 0.4136
# Epoch 168/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7642 - loss: 0.5198 - val_accuracy: 0.8686 - val_loss: 0.4125
# Epoch 169/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7325 - loss: 0.5216 - val_accuracy: 0.8686 - val_loss: 0.4117
# Epoch 170/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7392 - loss: 0.5189 - val_accuracy: 0.8686 - val_loss: 0.4109
# Epoch 171/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7617 - loss: 0.5075 - val_accuracy: 0.8686 - val_loss: 0.4099
# Epoch 172/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7717 - loss: 0.5028 - val_accuracy: 0.8686 - val_loss: 0.4077
# Epoch 173/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7592 - loss: 0.5048 - val_accuracy: 0.8714 - val_loss: 0.4040
# Epoch 174/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7583 - loss: 0.5044 - val_accuracy: 0.8743 - val_loss: 0.4030
# Epoch 175/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7658 - loss: 0.5026 - val_accuracy: 0.8743 - val_loss: 0.4024
# Epoch 176/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7558 - loss: 0.4893 - val_accuracy: 0.8743 - val_loss: 0.4005
# Epoch 177/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7883 - loss: 0.5007 - val_accuracy: 0.8714 - val_loss: 0.4005
# Epoch 178/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7583 - loss: 0.4980 - val_accuracy: 0.8714 - val_loss: 0.3985
# Epoch 179/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7717 - loss: 0.5090 - val_accuracy: 0.8714 - val_loss: 0.3961
# Epoch 180/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7617 - loss: 0.5025 - val_accuracy: 0.8743 - val_loss: 0.3943
# Epoch 181/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7700 - loss: 0.4975 - val_accuracy: 0.8743 - val_loss: 0.3933
# Epoch 182/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7675 - loss: 0.4965 - val_accuracy: 0.8743 - val_loss: 0.3920
# Epoch 183/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7750 - loss: 0.4929 - val_accuracy: 0.8743 - val_loss: 0.3909
# Epoch 184/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7500 - loss: 0.5166 - val_accuracy: 0.8771 - val_loss: 0.3913
# Epoch 185/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7783 - loss: 0.4831 - val_accuracy: 0.8771 - val_loss: 0.3888
# Epoch 186/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7708 - loss: 0.4889 - val_accuracy: 0.8771 - val_loss: 0.3876
# Epoch 187/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7708 - loss: 0.4912 - val_accuracy: 0.8771 - val_loss: 0.3875
# Epoch 188/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7775 - loss: 0.4814 - val_accuracy: 0.8829 - val_loss: 0.3855
# Epoch 189/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7817 - loss: 0.4901 - val_accuracy: 0.8771 - val_loss: 0.3843
# Epoch 190/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7725 - loss: 0.5000 - val_accuracy: 0.8771 - val_loss: 0.3841
# Epoch 191/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7758 - loss: 0.4945 - val_accuracy: 0.8800 - val_loss: 0.3830
# Epoch 192/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7733 - loss: 0.4878 - val_accuracy: 0.8800 - val_loss: 0.3809
# Epoch 193/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7875 - loss: 0.4887 - val_accuracy: 0.8857 - val_loss: 0.3792
# Epoch 194/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7925 - loss: 0.4857 - val_accuracy: 0.8857 - val_loss: 0.3775
# Epoch 195/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7908 - loss: 0.4831 - val_accuracy: 0.8886 - val_loss: 0.3752
# Epoch 196/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7717 - loss: 0.4911 - val_accuracy: 0.8829 - val_loss: 0.3754
# Epoch 197/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7825 - loss: 0.4898 - val_accuracy: 0.8829 - val_loss: 0.3745
# Epoch 198/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7708 - loss: 0.4793 - val_accuracy: 0.8829 - val_loss: 0.3730
# Epoch 199/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7783 - loss: 0.4924 - val_accuracy: 0.8829 - val_loss: 0.3724
# Epoch 200/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8108 - loss: 0.4730 - val_accuracy: 0.8886 - val_loss: 0.3715
# Epoch 201/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7833 - loss: 0.4839 - val_accuracy: 0.8857 - val_loss: 0.3701
# Epoch 202/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7867 - loss: 0.4756 - val_accuracy: 0.8914 - val_loss: 0.3697
# Epoch 203/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7858 - loss: 0.4768 - val_accuracy: 0.8857 - val_loss: 0.3693
# Epoch 204/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7883 - loss: 0.4714 - val_accuracy: 0.8857 - val_loss: 0.3677
# Epoch 205/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7792 - loss: 0.4724 - val_accuracy: 0.8886 - val_loss: 0.3655
# Epoch 206/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7792 - loss: 0.4796 - val_accuracy: 0.8857 - val_loss: 0.3648
# Epoch 207/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7925 - loss: 0.4456 - val_accuracy: 0.8886 - val_loss: 0.3625
# Epoch 208/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7908 - loss: 0.4881 - val_accuracy: 0.8914 - val_loss: 0.3624
# Epoch 209/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7942 - loss: 0.4485 - val_accuracy: 0.8857 - val_loss: 0.3601
# Epoch 210/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8100 - loss: 0.4655 - val_accuracy: 0.8886 - val_loss: 0.3593
# Epoch 211/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7808 - loss: 0.4600 - val_accuracy: 0.8914 - val_loss: 0.3586
# Epoch 212/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7833 - loss: 0.4787 - val_accuracy: 0.8943 - val_loss: 0.3570
# Epoch 213/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7892 - loss: 0.4638 - val_accuracy: 0.8857 - val_loss: 0.3555
# Epoch 214/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7742 - loss: 0.4692 - val_accuracy: 0.8914 - val_loss: 0.3537
# Epoch 215/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7975 - loss: 0.4782 - val_accuracy: 0.8914 - val_loss: 0.3535
# Epoch 216/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7958 - loss: 0.4712 - val_accuracy: 0.8943 - val_loss: 0.3536
# Epoch 217/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8017 - loss: 0.4518 - val_accuracy: 0.8971 - val_loss: 0.3521
# Epoch 218/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7767 - loss: 0.4798 - val_accuracy: 0.8971 - val_loss: 0.3508
# Epoch 219/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7850 - loss: 0.4737 - val_accuracy: 0.8971 - val_loss: 0.3503
# Epoch 220/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8067 - loss: 0.4562 - val_accuracy: 0.8971 - val_loss: 0.3481
# Epoch 221/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7858 - loss: 0.4756 - val_accuracy: 0.8971 - val_loss: 0.3479
# Epoch 222/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7908 - loss: 0.4752 - val_accuracy: 0.9000 - val_loss: 0.3470
# Epoch 223/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8058 - loss: 0.4526 - val_accuracy: 0.9029 - val_loss: 0.3457
# Epoch 224/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7917 - loss: 0.4652 - val_accuracy: 0.9029 - val_loss: 0.3452
# Epoch 225/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7983 - loss: 0.4573 - val_accuracy: 0.9029 - val_loss: 0.3437
# Epoch 226/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7925 - loss: 0.4597 - val_accuracy: 0.9029 - val_loss: 0.3429
# Epoch 227/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7825 - loss: 0.4688 - val_accuracy: 0.9029 - val_loss: 0.3425
# Epoch 228/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7917 - loss: 0.4552 - val_accuracy: 0.9029 - val_loss: 0.3416
# Epoch 229/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7958 - loss: 0.4604 - val_accuracy: 0.9029 - val_loss: 0.3408
# Epoch 230/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7917 - loss: 0.4626 - val_accuracy: 0.9029 - val_loss: 0.3389
# Epoch 231/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8142 - loss: 0.4448 - val_accuracy: 0.9029 - val_loss: 0.3378
# Epoch 232/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7867 - loss: 0.4462 - val_accuracy: 0.9029 - val_loss: 0.3363
# Epoch 233/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8158 - loss: 0.4500 - val_accuracy: 0.9029 - val_loss: 0.3353
# Epoch 234/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7983 - loss: 0.4490 - val_accuracy: 0.9029 - val_loss: 0.3333
# Epoch 235/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8042 - loss: 0.4371 - val_accuracy: 0.8971 - val_loss: 0.3314
# Epoch 236/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8017 - loss: 0.4562 - val_accuracy: 0.9057 - val_loss: 0.3301
# Epoch 237/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8025 - loss: 0.4565 - val_accuracy: 0.9057 - val_loss: 0.3288
# Epoch 238/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7967 - loss: 0.4555 - val_accuracy: 0.9000 - val_loss: 0.3286
# Epoch 239/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8083 - loss: 0.4391 - val_accuracy: 0.9000 - val_loss: 0.3273
# Epoch 240/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7958 - loss: 0.4601 - val_accuracy: 0.8971 - val_loss: 0.3270
# Epoch 241/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7883 - loss: 0.4564 - val_accuracy: 0.8971 - val_loss: 0.3261
# Epoch 242/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8058 - loss: 0.4494 - val_accuracy: 0.9029 - val_loss: 0.3248
# Epoch 243/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8067 - loss: 0.4419 - val_accuracy: 0.9000 - val_loss: 0.3240
# Epoch 244/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8225 - loss: 0.4382 - val_accuracy: 0.9029 - val_loss: 0.3232
# Epoch 245/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7783 - loss: 0.4760 - val_accuracy: 0.9057 - val_loss: 0.3225
# Epoch 246/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8133 - loss: 0.4269 - val_accuracy: 0.9086 - val_loss: 0.3216
# Epoch 247/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8100 - loss: 0.4394 - val_accuracy: 0.9086 - val_loss: 0.3210
# Epoch 248/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8025 - loss: 0.4505 - val_accuracy: 0.9057 - val_loss: 0.3204
# Epoch 249/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7917 - loss: 0.4385 - val_accuracy: 0.9086 - val_loss: 0.3194
# Epoch 250/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8058 - loss: 0.4509 - val_accuracy: 0.9114 - val_loss: 0.3189
# Epoch 251/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8117 - loss: 0.4545 - val_accuracy: 0.9114 - val_loss: 0.3181
# Epoch 252/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8200 - loss: 0.4163 - val_accuracy: 0.9114 - val_loss: 0.3173
# Epoch 253/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8100 - loss: 0.4478 - val_accuracy: 0.9114 - val_loss: 0.3172
# Epoch 254/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8158 - loss: 0.4223 - val_accuracy: 0.9114 - val_loss: 0.3161
# Epoch 255/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8083 - loss: 0.4211 - val_accuracy: 0.9114 - val_loss: 0.3147
# Epoch 256/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8083 - loss: 0.4505 - val_accuracy: 0.9114 - val_loss: 0.3137
# Epoch 257/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8000 - loss: 0.4297 - val_accuracy: 0.9114 - val_loss: 0.3131
# Epoch 258/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8100 - loss: 0.4381 - val_accuracy: 0.9114 - val_loss: 0.3122
# Epoch 259/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8200 - loss: 0.4251 - val_accuracy: 0.9057 - val_loss: 0.3106
# Epoch 260/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7883 - loss: 0.4532 - val_accuracy: 0.9114 - val_loss: 0.3105
# Epoch 261/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8167 - loss: 0.4175 - val_accuracy: 0.9114 - val_loss: 0.3100
# Epoch 262/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8175 - loss: 0.4152 - val_accuracy: 0.9114 - val_loss: 0.3087
# Epoch 263/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8217 - loss: 0.4257 - val_accuracy: 0.9114 - val_loss: 0.3083
# Epoch 264/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8108 - loss: 0.4238 - val_accuracy: 0.9114 - val_loss: 0.3071
# Epoch 265/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8233 - loss: 0.4362 - val_accuracy: 0.9143 - val_loss: 0.3062
# Epoch 266/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8150 - loss: 0.4374 - val_accuracy: 0.9143 - val_loss: 0.3053
# Epoch 267/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8025 - loss: 0.4179 - val_accuracy: 0.9143 - val_loss: 0.3043
# Epoch 268/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8150 - loss: 0.4146 - val_accuracy: 0.9114 - val_loss: 0.3034
# Epoch 269/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8317 - loss: 0.4054 - val_accuracy: 0.9143 - val_loss: 0.3024
# Epoch 270/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8117 - loss: 0.4152 - val_accuracy: 0.9143 - val_loss: 0.3016
# Epoch 271/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8017 - loss: 0.4377 - val_accuracy: 0.9143 - val_loss: 0.3016
# Epoch 272/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8125 - loss: 0.4255 - val_accuracy: 0.9143 - val_loss: 0.3013
# Epoch 273/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8092 - loss: 0.4257 - val_accuracy: 0.9143 - val_loss: 0.3005
# Epoch 274/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8242 - loss: 0.4072 - val_accuracy: 0.9143 - val_loss: 0.2999
# Epoch 275/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8192 - loss: 0.4274 - val_accuracy: 0.9143 - val_loss: 0.2997
# Epoch 276/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8142 - loss: 0.4198 - val_accuracy: 0.9171 - val_loss: 0.2994
# Epoch 277/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8075 - loss: 0.4150 - val_accuracy: 0.9171 - val_loss: 0.2976
# Epoch 278/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8042 - loss: 0.4042 - val_accuracy: 0.9171 - val_loss: 0.2969
# Epoch 279/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8133 - loss: 0.4136 - val_accuracy: 0.9171 - val_loss: 0.2968
# Epoch 280/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8300 - loss: 0.4053 - val_accuracy: 0.9171 - val_loss: 0.2965
# Epoch 281/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8142 - loss: 0.4190 - val_accuracy: 0.9171 - val_loss: 0.2960
# Epoch 282/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8233 - loss: 0.4256 - val_accuracy: 0.9171 - val_loss: 0.2954
# Epoch 283/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8225 - loss: 0.4153 - val_accuracy: 0.9171 - val_loss: 0.2949
# Epoch 284/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7992 - loss: 0.4287 - val_accuracy: 0.9171 - val_loss: 0.2937
# Epoch 285/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8208 - loss: 0.4132 - val_accuracy: 0.9200 - val_loss: 0.2932
# Epoch 286/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8050 - loss: 0.4135 - val_accuracy: 0.9171 - val_loss: 0.2928
# Epoch 287/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8425 - loss: 0.4195 - val_accuracy: 0.9171 - val_loss: 0.2926
# Epoch 288/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8417 - loss: 0.3915 - val_accuracy: 0.9171 - val_loss: 0.2910
# Epoch 289/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8375 - loss: 0.4083 - val_accuracy: 0.9171 - val_loss: 0.2900
# Epoch 290/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8317 - loss: 0.4072 - val_accuracy: 0.9171 - val_loss: 0.2895
# Epoch 291/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8408 - loss: 0.4085 - val_accuracy: 0.9200 - val_loss: 0.2887
# Epoch 292/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8400 - loss: 0.3982 - val_accuracy: 0.9200 - val_loss: 0.2879
# Epoch 293/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8317 - loss: 0.4150 - val_accuracy: 0.9200 - val_loss: 0.2877
# Epoch 294/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8383 - loss: 0.4400 - val_accuracy: 0.9200 - val_loss: 0.2877
# Epoch 295/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8225 - loss: 0.4301 - val_accuracy: 0.9171 - val_loss: 0.2875
# Epoch 296/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8317 - loss: 0.4167 - val_accuracy: 0.9200 - val_loss: 0.2869
# Epoch 297/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8283 - loss: 0.4093 - val_accuracy: 0.9200 - val_loss: 0.2859
# Epoch 298/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.4053 - val_accuracy: 0.9200 - val_loss: 0.2850
# Epoch 299/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8333 - loss: 0.4169 - val_accuracy: 0.9200 - val_loss: 0.2848
# Epoch 300/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8342 - loss: 0.4140 - val_accuracy: 0.9229 - val_loss: 0.2842
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       191
#            1       0.91      0.92      0.92       159
#
#     accuracy                           0.92       350
#    macro avg       0.92      0.92      0.92       350
# weighted avg       0.92      0.92      0.92       350

# %% [markdown]
# ### (3) 방법 2: 추가 학습
#
# - 기본 모델을 기반으로 모델을 선언하고 추가 학습 후 성능을 확인합니다.

# %%
# 방법 2: 기본 모델에 추가 학습
model2 = load_model(path + 'base_model.keras')
model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        10,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,445 (240.02 KB)
#  Trainable params: 20,481 (80.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 40,964 (160.02 KB)

# %% [markdown]
# - 학습 방법을 설정하고 학습을 수행합니다.

# %%
# 방법 2: 기본 모델 불러와 이어 학습 (Continued Training) - new_train 데이터만 사용

es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model2.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
history2 = model2.fit(x_train_new_data, y_train_new_data, epochs=300, batch_size=32, validation_data=(x_val, y_val), callbacks=[es], verbose=1, class_weight=class_weight_dict_new_data)
# Out:
# Epoch 1/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.5635 - loss: 3.2027 - val_accuracy: 0.5543 - val_loss: 3.2814
# Epoch 2/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6247 - loss: 2.2763 - val_accuracy: 0.5914 - val_loss: 2.5734
# Epoch 3/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6647 - loss: 1.7832 - val_accuracy: 0.6400 - val_loss: 2.0403
# Epoch 4/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7024 - loss: 1.4415 - val_accuracy: 0.6800 - val_loss: 1.6482
# Epoch 5/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7365 - loss: 1.1702 - val_accuracy: 0.7057 - val_loss: 1.3686
# Epoch 6/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7424 - loss: 1.0171 - val_accuracy: 0.7171 - val_loss: 1.1617
# Epoch 7/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7612 - loss: 0.8301 - val_accuracy: 0.7143 - val_loss: 0.9949
# Epoch 8/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7812 - loss: 0.7618 - val_accuracy: 0.7400 - val_loss: 0.8830
# Epoch 9/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7788 - loss: 0.6553 - val_accuracy: 0.7543 - val_loss: 0.8037
# Epoch 10/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8094 - loss: 0.6507 - val_accuracy: 0.7571 - val_loss: 0.7374
# Epoch 11/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7976 - loss: 0.6298 - val_accuracy: 0.7486 - val_loss: 0.6850
# Epoch 12/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8035 - loss: 0.5333 - val_accuracy: 0.7657 - val_loss: 0.6410
# Epoch 13/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8176 - loss: 0.5422 - val_accuracy: 0.7657 - val_loss: 0.6215
# Epoch 14/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8365 - loss: 0.4830 - val_accuracy: 0.7657 - val_loss: 0.5992
# Epoch 15/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8224 - loss: 0.4889 - val_accuracy: 0.7771 - val_loss: 0.5781
# Epoch 16/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8294 - loss: 0.5047 - val_accuracy: 0.7771 - val_loss: 0.5616
# Epoch 17/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8306 - loss: 0.5189 - val_accuracy: 0.7771 - val_loss: 0.5481
# Epoch 18/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8341 - loss: 0.4886 - val_accuracy: 0.7857 - val_loss: 0.5312
# Epoch 19/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8388 - loss: 0.4135 - val_accuracy: 0.7971 - val_loss: 0.5208
# Epoch 20/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8294 - loss: 0.4553 - val_accuracy: 0.7943 - val_loss: 0.5112
# Epoch 21/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8435 - loss: 0.4432 - val_accuracy: 0.7943 - val_loss: 0.5024
# Epoch 22/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8412 - loss: 0.4525 - val_accuracy: 0.7943 - val_loss: 0.4954
# Epoch 23/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8506 - loss: 0.4096 - val_accuracy: 0.7914 - val_loss: 0.4875
# Epoch 24/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8424 - loss: 0.4272 - val_accuracy: 0.7914 - val_loss: 0.4801
# Epoch 25/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8518 - loss: 0.3925 - val_accuracy: 0.7914 - val_loss: 0.4735
# Epoch 26/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8635 - loss: 0.3386 - val_accuracy: 0.7943 - val_loss: 0.4688
# Epoch 27/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8518 - loss: 0.3853 - val_accuracy: 0.8000 - val_loss: 0.4629
# Epoch 28/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8553 - loss: 0.3688 - val_accuracy: 0.8000 - val_loss: 0.4595
# Epoch 29/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8635 - loss: 0.3550 - val_accuracy: 0.8029 - val_loss: 0.4547
# Epoch 30/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8541 - loss: 0.3761 - val_accuracy: 0.8086 - val_loss: 0.4505
# Epoch 31/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8553 - loss: 0.3681 - val_accuracy: 0.8029 - val_loss: 0.4462
# Epoch 32/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8635 - loss: 0.3317 - val_accuracy: 0.8086 - val_loss: 0.4452
# Epoch 33/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8647 - loss: 0.3397 - val_accuracy: 0.8114 - val_loss: 0.4427
# Epoch 34/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8588 - loss: 0.3516 - val_accuracy: 0.8143 - val_loss: 0.4403
# Epoch 35/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8729 - loss: 0.3383 - val_accuracy: 0.8143 - val_loss: 0.4401
# Epoch 36/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8612 - loss: 0.3539 - val_accuracy: 0.8143 - val_loss: 0.4366
# Epoch 37/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8741 - loss: 0.3288 - val_accuracy: 0.8143 - val_loss: 0.4361
# Epoch 38/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8882 - loss: 0.3217 - val_accuracy: 0.8171 - val_loss: 0.4336
# Epoch 39/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8847 - loss: 0.3070 - val_accuracy: 0.8171 - val_loss: 0.4313
# Epoch 40/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8776 - loss: 0.3499 - val_accuracy: 0.8200 - val_loss: 0.4282
# Epoch 41/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8624 - loss: 0.3235 - val_accuracy: 0.8229 - val_loss: 0.4269
# Epoch 42/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8741 - loss: 0.2880 - val_accuracy: 0.8200 - val_loss: 0.4265
# Epoch 43/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8894 - loss: 0.3028 - val_accuracy: 0.8200 - val_loss: 0.4255
# Epoch 44/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8929 - loss: 0.3065 - val_accuracy: 0.8200 - val_loss: 0.4250
# Epoch 45/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8859 - loss: 0.3015 - val_accuracy: 0.8171 - val_loss: 0.4235
# Epoch 46/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8882 - loss: 0.3136 - val_accuracy: 0.8229 - val_loss: 0.4242
# Epoch 47/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8800 - loss: 0.2864 - val_accuracy: 0.8229 - val_loss: 0.4229
# Epoch 48/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8741 - loss: 0.2909 - val_accuracy: 0.8229 - val_loss: 0.4209
# Epoch 49/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8753 - loss: 0.3130 - val_accuracy: 0.8257 - val_loss: 0.4202
# Epoch 50/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8859 - loss: 0.3068 - val_accuracy: 0.8257 - val_loss: 0.4180
# Epoch 51/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9012 - loss: 0.2714 - val_accuracy: 0.8286 - val_loss: 0.4161
# Epoch 52/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8918 - loss: 0.2951 - val_accuracy: 0.8286 - val_loss: 0.4129
# Epoch 53/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8859 - loss: 0.2968 - val_accuracy: 0.8286 - val_loss: 0.4124
# Epoch 54/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9012 - loss: 0.2576 - val_accuracy: 0.8286 - val_loss: 0.4121
# Epoch 55/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9012 - loss: 0.2841 - val_accuracy: 0.8314 - val_loss: 0.4113
# Epoch 56/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9047 - loss: 0.2544 - val_accuracy: 0.8286 - val_loss: 0.4112
# Epoch 57/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9000 - loss: 0.2742 - val_accuracy: 0.8286 - val_loss: 0.4112
# Epoch 58/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9012 - loss: 0.2494 - val_accuracy: 0.8286 - val_loss: 0.4114
# Epoch 59/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8953 - loss: 0.2772 - val_accuracy: 0.8257 - val_loss: 0.4129
# Epoch 60/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8965 - loss: 0.2668 - val_accuracy: 0.8229 - val_loss: 0.4134
# Epoch 61/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9106 - loss: 0.2473 - val_accuracy: 0.8229 - val_loss: 0.4141
# Epoch 62/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9118 - loss: 0.2341 - val_accuracy: 0.8229 - val_loss: 0.4133
# Epoch 63/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9047 - loss: 0.2537 - val_accuracy: 0.8257 - val_loss: 0.4128
# Epoch 64/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9141 - loss: 0.2523 - val_accuracy: 0.8229 - val_loss: 0.4153
# Epoch 65/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8988 - loss: 0.2736 - val_accuracy: 0.8257 - val_loss: 0.4117
# Epoch 66/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9082 - loss: 0.2321 - val_accuracy: 0.8257 - val_loss: 0.4122
# Epoch 67/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9200 - loss: 0.2291 - val_accuracy: 0.8257 - val_loss: 0.4127

# %% [markdown]
# - 학습 곡선을 확인합니다.

# %%
# 학습 곡선 확인
dl_history_plot(history2.history)

# %% [markdown]
# - 검증 데이터로 예측 및 평가를 수행합니다.

# %%
# 검증 데이터 평가
y_pred2 = model2.predict(x_val)
y_pred2 = (y_pred2 > 0.5).astype(int)

print(classification_report(y_val, y_pred2))
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84       191
#            1       0.80      0.84      0.82       159
#
#     accuracy                           0.83       350
#    macro avg       0.83      0.83      0.83       350
# weighted avg       0.83      0.83      0.83       350

# %% [markdown]
# ### (4) 방법 3: 미세조정
#
# - 기본 모델의 앞쪽 레이어 일부의 학습 기능을 비활성화합니다.
# - 기본 모델을 기반으로 레이어를 추가한 모델을 선언합니다.
# - 추가 학습을 진행한 뒤 성능을 확인합니다.

# %%
# 방법 3: Fine-tuning
clear_session()

# 기본 모델 불러오기
base_model_ft = load_model(path + 'base_model.keras')

# 원본 모델의 출력층 제거
base_model_ft.pop()

# 기본 모델의 모든 레이어를 동결 (feature extractor로 사용)
for layer in base_model_ft.layers:
    layer.trainable = False

# 새로운 출력층을 추가하여 Fine-tuning 모델 구성
model3 = Sequential([
    base_model_ft,
    Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.001)), # 새로운 은닉층 추가
    Dropout(0.3),
    Dense(1, activation='sigmoid') # 새로운 출력층
])

model3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 32)             │        20,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,721 (80.94 KB)
#  Trainable params: 273 (1.07 KB)
#  Non-trainable params: 20,448 (79.88 KB)

# %%
# 방법 3: Fine-tuning
clear_session()

# 이전 단계에서 선택된 더 좋은 모델 불러오기
base_model_ft = model1

# 원본 모델의 출력층 제거 (새로운 출력층을 추가하기 위함)
# 모델에 따라 출력층이 여러 개일 수 있으므로, 마지막 출력층을 가정합니다.
# 만약 모델 구조가 복잡하여 pop()으로 출력층 제거가 어렵다면, 새로운 Sequential 모델을 구성해야 합니다.
if base_model_ft.layers:
    base_model_ft.pop()

# 기본 모델의 모든 레이어를 동결 (feature extractor로 사용)
#for layer in base_model_ft.layers:
#    layer.trainable = False

for layer in base_model.layers[:-5]:
    layer.trainable = False

# 새로운 출력층을 추가하여 Fine-tuning 모델 구성
model3 = Sequential([
    base_model_ft,
    #Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.001)), # 새로운 은닉층 추가
    Dense(8, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid') # 새로운 출력층
])

model3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 32)             │         2,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,801 (10.94 KB)
#  Trainable params: 273 (1.07 KB)
#  Non-trainable params: 2,528 (9.88 KB)

# %% [markdown]
# - 학습 방법을 설정하고 학습을 수행합니다.

# %%
# 학습 설정 및 수행 - new_train 데이터만 사용
model3.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history3 = model3.fit(x_train_new_data, y_train_new_data, epochs=200, batch_size=32, validation_data=(x_val, y_val), callbacks=[es], verbose=1, class_weight=class_weight_dict_new_data)
# Out:
# Epoch 1/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.4000 - loss: 0.7311 - val_accuracy: 0.4429 - val_loss: 0.7064
# Epoch 2/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5482 - loss: 0.6888 - val_accuracy: 0.7543 - val_loss: 0.6644
# Epoch 3/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7247 - loss: 0.6424 - val_accuracy: 0.8771 - val_loss: 0.6183
# Epoch 4/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8106 - loss: 0.5907 - val_accuracy: 0.9000 - val_loss: 0.5662
# Epoch 5/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8365 - loss: 0.5406 - val_accuracy: 0.9057 - val_loss: 0.5120
# Epoch 6/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8553 - loss: 0.4954 - val_accuracy: 0.9057 - val_loss: 0.4595
# Epoch 7/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8882 - loss: 0.4360 - val_accuracy: 0.9171 - val_loss: 0.4133
# Epoch 8/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8941 - loss: 0.3990 - val_accuracy: 0.9229 - val_loss: 0.3771
# Epoch 9/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8871 - loss: 0.3786 - val_accuracy: 0.9229 - val_loss: 0.3515
# Epoch 10/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8918 - loss: 0.3593 - val_accuracy: 0.9229 - val_loss: 0.3317
# Epoch 11/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9012 - loss: 0.3429 - val_accuracy: 0.9286 - val_loss: 0.3162
# Epoch 12/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9118 - loss: 0.3218 - val_accuracy: 0.9286 - val_loss: 0.3039
# Epoch 13/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9035 - loss: 0.3083 - val_accuracy: 0.9257 - val_loss: 0.2925
# Epoch 14/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9165 - loss: 0.2839 - val_accuracy: 0.9257 - val_loss: 0.2833
# Epoch 15/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9106 - loss: 0.3010 - val_accuracy: 0.9257 - val_loss: 0.2765
# Epoch 16/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8965 - loss: 0.2983 - val_accuracy: 0.9286 - val_loss: 0.2710
# Epoch 17/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9141 - loss: 0.2790 - val_accuracy: 0.9286 - val_loss: 0.2660
# Epoch 18/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9035 - loss: 0.2894 - val_accuracy: 0.9286 - val_loss: 0.2619
# Epoch 19/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9106 - loss: 0.2732 - val_accuracy: 0.9343 - val_loss: 0.2597
# Epoch 20/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9094 - loss: 0.2741 - val_accuracy: 0.9343 - val_loss: 0.2560
# Epoch 21/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9024 - loss: 0.2678 - val_accuracy: 0.9314 - val_loss: 0.2532
# Epoch 22/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9188 - loss: 0.2699 - val_accuracy: 0.9314 - val_loss: 0.2512
# Epoch 23/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9012 - loss: 0.2675 - val_accuracy: 0.9343 - val_loss: 0.2501
# Epoch 24/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9118 - loss: 0.2562 - val_accuracy: 0.9286 - val_loss: 0.2483
# Epoch 25/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9094 - loss: 0.2600 - val_accuracy: 0.9257 - val_loss: 0.2468
# Epoch 26/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9118 - loss: 0.2541 - val_accuracy: 0.9257 - val_loss: 0.2452
# Epoch 27/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9106 - loss: 0.2616 - val_accuracy: 0.9257 - val_loss: 0.2438
# Epoch 28/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9094 - loss: 0.2533 - val_accuracy: 0.9229 - val_loss: 0.2430
# Epoch 29/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9106 - loss: 0.2529 - val_accuracy: 0.9229 - val_loss: 0.2426
# Epoch 30/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9200 - loss: 0.2562 - val_accuracy: 0.9229 - val_loss: 0.2418
# Epoch 31/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9235 - loss: 0.2475 - val_accuracy: 0.9229 - val_loss: 0.2409
# Epoch 32/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9224 - loss: 0.2537 - val_accuracy: 0.9229 - val_loss: 0.2405
# Epoch 33/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9082 - loss: 0.2528 - val_accuracy: 0.9229 - val_loss: 0.2398
# Epoch 34/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9071 - loss: 0.2577 - val_accuracy: 0.9229 - val_loss: 0.2393
# Epoch 35/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9118 - loss: 0.2514 - val_accuracy: 0.9229 - val_loss: 0.2385
# Epoch 36/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9188 - loss: 0.2305 - val_accuracy: 0.9229 - val_loss: 0.2379
# Epoch 37/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9129 - loss: 0.2465 - val_accuracy: 0.9229 - val_loss: 0.2378
# Epoch 38/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9200 - loss: 0.2446 - val_accuracy: 0.9229 - val_loss: 0.2375
# Epoch 39/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9224 - loss: 0.2243 - val_accuracy: 0.9229 - val_loss: 0.2364
# Epoch 40/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9106 - loss: 0.2490 - val_accuracy: 0.9229 - val_loss: 0.2361
# Epoch 41/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9129 - loss: 0.2398 - val_accuracy: 0.9200 - val_loss: 0.2362
# Epoch 42/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9200 - loss: 0.2357 - val_accuracy: 0.9229 - val_loss: 0.2353
# Epoch 43/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9082 - loss: 0.2632 - val_accuracy: 0.9200 - val_loss: 0.2356
# Epoch 44/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9118 - loss: 0.2409 - val_accuracy: 0.9200 - val_loss: 0.2354
# Epoch 45/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9106 - loss: 0.2446 - val_accuracy: 0.9200 - val_loss: 0.2349
# Epoch 46/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9176 - loss: 0.2422 - val_accuracy: 0.9200 - val_loss: 0.2355
# Epoch 47/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9188 - loss: 0.2337 - val_accuracy: 0.9200 - val_loss: 0.2356
# Epoch 48/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9224 - loss: 0.2355 - val_accuracy: 0.9200 - val_loss: 0.2361
# Epoch 49/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9141 - loss: 0.2380 - val_accuracy: 0.9171 - val_loss: 0.2364
# Epoch 50/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9200 - loss: 0.2402 - val_accuracy: 0.9200 - val_loss: 0.2357
# Epoch 51/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9129 - loss: 0.2374 - val_accuracy: 0.9200 - val_loss: 0.2354
# Epoch 52/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9200 - loss: 0.2333 - val_accuracy: 0.9200 - val_loss: 0.2350
# Epoch 53/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9212 - loss: 0.2198 - val_accuracy: 0.9171 - val_loss: 0.2358
# Epoch 54/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9212 - loss: 0.2249 - val_accuracy: 0.9200 - val_loss: 0.2354
# Epoch 55/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9118 - loss: 0.2290 - val_accuracy: 0.9171 - val_loss: 0.2354

# %% [markdown]
# - 학습 곡선을 확인합니다.

# %%
# 학습 곡선 확인
dl_history_plot(history3.history)

# %% [markdown]
# - 검증 데이터로 예측 및 평가를 수행합니다.

# %%
# 검증 데이터 평가
y_pred3 = model3.predict(x_val)
y_pred3_class = (y_pred3 > 0.63).astype(int)


print(classification_report(y_val, y_pred3_class))
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       191
#            1       0.93      0.91      0.92       159
#
#     accuracy                           0.93       350
#    macro avg       0.93      0.92      0.92       350
# weighted avg       0.93      0.93      0.93       350

# %%
# 임계값 그리드 서치
from sklearn.metrics import recall_score

MIN_RECALL = 0.9 # 원하는 최소 recall

candidates = [(t, recall_score(y_val, (y_pred3 > t).astype(int)))
              for t in np.arange(0.1, 0.91, 0.01)]

# recall >= 기준을 만족하는 것 중 threshold가 가장 높은 것 (= precision 최대)
valid = [(t, r) for t, r in candidates if r >= MIN_RECALL]
best_threshold = max(valid, key=lambda x: x[0])[0]
print(f"최적 임계값: {best_threshold:.2f}")
# Out:
# 최적 임계값: 0.63
