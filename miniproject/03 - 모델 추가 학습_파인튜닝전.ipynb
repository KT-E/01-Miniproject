# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/satisfaction.png'/></center>

# %% [markdown]
# ### **고객 만족도 예측을 통한 서비스 개선**
# # **단계 3: 모델 추가 학습**

# %% [markdown]
# ## **미션 설명**
#
# - 이번 단계에서는 다음과 같이 3개의 미션을 수행합니다.

# %% [markdown]
# ### 미션 8: 전처리 파이프라인 만들기
#
# - 새로운 학습용/검증용 데이터에 대해 매번 전처리 작업을 수행해야 합니다.
# - 반복되는 전처리 작업은 비효율적인 업무 중 하나입니다.
# - 이러한 문제를 해결하기 위해 다음과 같은 처리를 일괄 수행하는 파이프라인 함수를 만듭니다.
#     - 결측치 처리
#     - Target 값 0/1로 변경
#     - 불필요한 변수 제거
#     - 라벨 인코딩
#     - 가변수화
#     - x, y 분리
#     - x 스케일링 등

# %% [markdown]
# ### 미션 9: 기본 모델로 예측 및 평가
#
# - 이전 과정에서 만든 모델이 기본 모델(Base Model)입니다.
# - 새로 전달 받은 평가용 데이터로 기존에 만든 모델의 성능을 평가해봅니다.

# %% [markdown]
# ### 미션 10: 추가 학습
#
# - 문제 상황에 맞게 가장 적절한 방법으로 모델 추가 학습을 진행합니다.
# - 추가 학습 후 이전에 평가했던 새로운 평가 데이터로 다시 평가해 성능 향상을 확인합니다.

# %% [markdown]
# ## **※ 코드 셀은 충분히 추가해 사용합니다.**

# %% [markdown]
# ## **1. 환경설정**

# %% [markdown]
# ### (1) 구글 드라이브 연결 및 경로 설정
#
# - 다음 구문을 실행에 구글 코랩에서 사용 가능하게 연결합니다.

# %%
# 구글 드라이브 연결 & 패스 지정
import sys
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    path = '/content/drive/MyDrive/KT-A/1-Data/project01/'
else:
    path = ''
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### (2) 라이브러리 불러오기
#
# - 이후에 사용할 라이브러리를 모두 불러옵니다.

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import *
from sklearn.utils import class_weight


from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.backend import clear_session
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

import joblib
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### (3) 학습 곡선 시각화 함수 만들기
#
# - 모델링 수행 시 학습 상황을 시각화해 확인하기 위한 함수를 만듭니다.

# %%
# 함수 만들기
def dl_history_plot(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history['loss'], label='Train Loss', marker='.')
    plt.plot(history['val_loss'], label='Validation Loss', marker='.')

    plt.title('Learning Curve', size=15, pad=20)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %% [markdown]
# ### (4) 기본 모델 및 데이터 불러오기
#
# - 우선 이전 과정에서 저장한 모델을 불러와 base_model로 선언합니다.
#     - path + 'base_model.keras' →  base_model
# - **load_model()** 함수를 사용합니다.

# %%
# 모델 불러오기
base_model = load_model(path + 'base_model.keras')

# %% [markdown]
# - 이전 과정에서 저장한 스케일러를 불러와 scaler 변수에 저장합니다.
#     - path + 'scaler.pkl' →  scaler
# - **joblib.load()** 함수를 사용합니다.

# %%
# 스케일러 불러오기
scaler = joblib.load(path + 'scaler.pkl')

# %% [markdown]
# - 이전 과정에서 저장한 파일을 읽어와 new_test, new_train 데이터프레임을 만듭니다.
#     - path + 'new_test.csv' → new_test
#     - path + 'new_train.csv' → new_train

# %%
# 파일 불러오기
new_test = pd.read_csv(path + 'new_test.csv')
new_train = pd.read_csv(path + 'new_train.csv')

# %%
# 기존 훈련 데이터 불러오기
original_df = pd.read_csv(path + 'data.csv')
print(original_df.shape)
# Out:
# (19278, 23)

# %%
new_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         850 non-null    int64
#  1   ID                                 850 non-null    int64
#  2   Gender                             850 non-null    object
#  3   Customer Type                      850 non-null    object
#  4   Age                                817 non-null    float64
#  5   Type of Travel                     850 non-null    object
#  6   Class                              850 non-null    object
#  7   Flight Distance                    850 non-null    int64
#  8   Inflight wifi service              830 non-null    float64
#  9   Departure/Arrival time convenient  850 non-null    int64
#  10  Ease of Online booking             850 non-null    int64
#  11  Gate location                      850 non-null    int64
#  12  Food and drink                     836 non-null    float64
#  13  Online boarding                    850 non-null    int64
#  14  Seat comfort                       823 non-null    float64
#  15  Inflight entertainment             850 non-null    int64
#  16  On-board service                   850 non-null    int64
#  17  Leg room service                   850 non-null    int64
#  18  Baggage handling                   850 non-null    int64
#  19  Checkin service                    850 non-null    int64
#  20  Inflight service                   850 non-null    int64
#  21  Cleanliness                        850 non-null    int64
#  22  Departure Delay in Minutes         850 non-null    int64
#  23  Arrival Delay in Minutes           847 non-null    float64
#  24  Satisfaction                       850 non-null    object
# dtypes: float64(5), int64(15), object(5)
# memory usage: 166.1+ KB

# %%
new_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         350 non-null    int64
#  1   ID                                 350 non-null    int64
#  2   Gender                             350 non-null    object
#  3   Customer Type                      350 non-null    object
#  4   Age                                340 non-null    float64
#  5   Type of Travel                     350 non-null    object
#  6   Class                              350 non-null    object
#  7   Flight Distance                    350 non-null    int64
#  8   Inflight wifi service              335 non-null    float64
#  9   Departure/Arrival time convenient  350 non-null    int64
#  10  Ease of Online booking             350 non-null    int64
#  11  Gate location                      350 non-null    int64
#  12  Food and drink                     342 non-null    float64
#  13  Online boarding                    350 non-null    int64
#  14  Seat comfort                       346 non-null    float64
#  15  Inflight entertainment             350 non-null    int64
#  16  On-board service                   350 non-null    int64
#  17  Leg room service                   350 non-null    int64
#  18  Baggage handling                   350 non-null    int64
#  19  Checkin service                    350 non-null    int64
#  20  Inflight service                   350 non-null    int64
#  21  Cleanliness                        350 non-null    int64
#  22  Departure Delay in Minutes         350 non-null    int64
#  23  Arrival Delay in Minutes           350 non-null    float64
#  24  Satisfaction                       350 non-null    object
# dtypes: float64(5), int64(15), object(5)
# memory usage: 68.5+ KB

# %%
new_test['Satisfaction'].value_counts()
# Out:
# Satisfaction
# Neutral or Dissatisfied    191
# Satisfied                  159
# Name: count, dtype: int64

# %%
new_train['Satisfaction'].value_counts()
# Out:
# Satisfaction
# Neutral or Dissatisfied    463
# Satisfied                  387
# Name: count, dtype: int64

# %%
new_train.describe()
# Out:
#           Unnamed: 0             ID         Age  Flight Distance  \
# count     850.000000     850.000000  817.000000       850.000000
# mean    52186.782353   68038.528235   38.887393      1243.060000
# std     30002.047030   37653.069414   15.507890      1010.359805
# min       271.000000      66.000000    7.000000        83.000000
# 25%     26769.500000   36066.500000   27.000000       436.000000
# 50%     51662.000000   68474.500000   40.000000       901.000000
# 75%     78419.000000  103302.500000   50.000000      1945.250000
# max    103687.000000  129690.000000   85.000000      4963.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count             830.000000                         850.000000
# mean                2.742169                           3.044706
# std                 1.328369                           1.507852
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count              850.000000     850.000000      836.000000       850.000000
# mean                 2.772941       3.015294        3.206938         3.260000
# std                  1.380999       1.263234        1.339050         1.329887
# min                  0.000000       1.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#        Seat comfort  Inflight entertainment  On-board service  \
# count    823.000000              850.000000        850.000000
# mean       3.465371                3.360000          3.372941
# std        1.325752                1.351107          1.299079
# min        1.000000                1.000000          1.000000
# 25%        2.000000                2.000000          2.000000
# 50%        4.000000                4.000000          4.000000
# 75%        5.000000                4.000000          4.000000
# max        5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count        850.000000        850.000000       850.000000        850.000000
# mean           3.330588          3.629412         3.295294          3.611765
# std            1.322143          1.204753         1.274411          1.193762
# min            0.000000          1.000000         1.000000          1.000000
# 25%            2.000000          3.000000         2.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count   850.000000                  850.000000                847.000000
# mean      3.274118                   14.455294                 14.981110
# std       1.330591                   37.173911                 37.835117
# min       1.000000                    0.000000                  0.000000
# 25%       2.000000                    0.000000                  0.000000
# 50%       3.000000                    0.000000                  0.000000
# 75%       4.000000                   10.000000                 11.000000
# max       5.000000                  319.000000                317.000000

# %%
new_test.describe()
# Out:
#           Unnamed: 0             ID         Age  Flight Distance  \
# count     350.000000     350.000000  340.000000       350.000000
# mean    48425.068571   65152.657143   39.658824      1208.000000
# std     29544.205709   37229.827120   15.664667       997.817797
# min       605.000000     421.000000    7.000000        67.000000
# 25%     23269.000000   33102.250000   26.000000       431.750000
# 50%     46005.500000   63395.000000   40.500000       877.000000
# 75%     73979.750000   99287.750000   52.000000      1711.000000
# max    103826.000000  129803.000000   80.000000      4963.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count             335.000000                         350.000000
# mean                2.650746                           3.125714
# std                 1.360408                           1.470306
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count              350.000000     350.000000      342.000000       350.000000
# mean                 2.711429       3.034286        3.251462         3.177143
# std                  1.414066       1.248023        1.309087         1.405084
# min                  0.000000       1.000000        1.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#        Seat comfort  Inflight entertainment  On-board service  \
# count    346.000000              350.000000        350.000000
# mean       3.473988                3.414286          3.434286
# std        1.319053                1.340282          1.332843
# min        1.000000                1.000000          1.000000
# 25%        2.250000                2.000000          2.000000
# 50%        4.000000                4.000000          4.000000
# 75%        5.000000                5.000000          5.000000
# max        5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count        350.000000        350.000000       350.000000        350.000000
# mean           3.348571          3.634286         3.428571          3.614286
# std            1.351508          1.183928         1.217958          1.217034
# min            0.000000          1.000000         1.000000          1.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         4.000000          4.000000
# 75%            5.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count   350.000000                  350.000000                350.000000
# mean      3.385714                   15.157143                 14.882857
# std       1.296821                   36.684138                 37.421099
# min       1.000000                    0.000000                  0.000000
# 25%       2.000000                    0.000000                  0.000000
# 50%       3.500000                    0.000000                  0.000000
# 75%       4.000000                   11.000000                  9.000000
# max       5.000000                  274.000000                310.000000

# %%
new_train.isnull().sum()
# Out:
# Unnamed: 0                            0
# ID                                    0
# Gender                                0
# Customer Type                         0
# Age                                  33
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                20
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                       14
# Online boarding                       0
# Seat comfort                         27
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes              3
# Satisfaction                          0
# dtype: int64

# %%
new_test.isnull().sum()
# Out:
# Unnamed: 0                            0
# ID                                    0
# Gender                                0
# Customer Type                         0
# Age                                  10
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                15
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        8
# Online boarding                       0
# Seat comfort                          4
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes              0
# Satisfaction                          0
# dtype: int64

# %% [markdown]
# ## **2. 미션 8: 전처리 파이프라인 만들기**
#
# - 다음 과정을 일괄 처리한 후 x, y를 반환하는 함수를 만듭니다.
#     - 결측치 처리
#     - Target 값 0/1로 변경
#     - 불필요한 변수 제거
#     - 라벨 인코딩
#     - 가변수화
#     - x, y 분리
#     - x 스케일링 등
# - 함수 이름은 **build_model_input** 로 지정합니다.
# - 다음과 같이 사용할 수 있어야 합니다.
#     - 예1) x_val, y_val = build_model_input(new_test)
#     - 예2) x_trian, y_train = build_model_input(new_train)
#
# ## **새로운 학습 전략:**
#
# ### **방법 1: 원본 데이터 + 새로운 학습/평가 데이터를 포함한 전체 데이터로 학습**
# - `original_df` (raw), `new_train`, `new_test` 를 합쳐서 `x_combined_train`, `y_combined_train`을 생성합니다.
# - `base_model`을 초기화하여 이 데이터로 다시 학습(`model1`).
#
# ### **방법 2: 새로운 학습 데이터(`new_train`)만으로 추가 학습**
# - `new_train` 데이터만으로 `x_train_new_data`, `y_train_new_data`를 생성합니다.
# - 기존 `base_model`에 `new_train` 데이터만으로 추가 학습(`model2`) 또는 미세 조정(`model3`).

# %%
# 결측치 처리전 확인
# Age
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Age'], kde=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Age'], kde=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# 결측치 처리전 확인
# Inflight wifi service
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Inflight wifi service'], kde=True)
plt.xlabel('Inflight wifi service')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Inflight wifi service'], kde=True)
plt.xlabel('Inflight wifi service')
plt.ylabel('Count')
plt.show()

# %%
# 결측치 처리전 확인
# Food and drink
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Food and drink'], kde=True)
plt.xlabel('Food and drink')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Food and drink'], kde=True)
plt.xlabel('Food and drink')
plt.ylabel('Count')
plt.show()

# %%
# 결측치 처리전 확인
# Seat comfort
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Seat comfort'], kde=True)
plt.xlabel('Seat comfort')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Seat comfort'], kde=True)
plt.xlabel('Seat comfort')
plt.ylabel('Count')
plt.show()

# %%
# 결측치 처리전 확인
# Arrival Delay in Minutes
plt.figure(figsize=(8, 5))
sns.histplot(new_train['Arrival Delay in Minutes'], kde=True)
plt.xlabel('Arrival Delay in Minutes')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(new_test['Arrival Delay in Minutes'], kde=True)
plt.xlabel('Arrival Delay in Minutes')
plt.ylabel('Count')
plt.show()

# %%
def build_model_input(data):
    df = data.copy()

    # 1. 결측치 처리 (수치형/점수형 변수)
    impute_cols = ['Age', 'Inflight wifi service', 'Food and drink', 'Seat comfort', 'Arrival Delay in Minutes']
    for col in impute_cols:
        if col in df.columns:
            df[col] = df[col].fillna(df[col].median())

    # 2. Target 값 변경 및 결측치 행 제거
    y = None
    if 'Satisfaction' in df.columns:
        df['Satisfaction'] = df['Satisfaction'].str.lower()
        df['Satisfaction'] = df['Satisfaction'].map({'satisfied': 1, 'neutral or dissatisfied': 0})

        df = df.dropna(subset=['Satisfaction'])

        if df.empty:
            return pd.DataFrame(), np.array([])

        y = df['Satisfaction'].values
        df.drop(columns=['Satisfaction'], inplace=True)

    # 3. 불필요한 변수 제거
    df.drop(columns=['Unnamed: 0', 'ID'], inplace=True, errors='ignore')

    # 4. 라벨 인코딩
    if 'Gender' in df.columns:
        df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
    if 'Customer Type' in df.columns:
        df['Customer Type'] = df['Customer Type'].str.lower().map({'loyal customer': 1, 'disloyal customer': 0})

    # 5. 가변수화
    cat_cols = ['Type of Travel', 'Class', 'Inflight wifi service', 'Departure/Arrival time convenient',
                'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding',
                'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service',
                'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness']
    existing_cat_cols = [c for c in cat_cols if c in df.columns]
    df = pd.get_dummies(df, columns=existing_cat_cols)

    # 6. 스케일러 피처와 일치시키기
    try:
        cols = scaler.feature_names_in_.tolist()
        for col in cols:
            if col not in df.columns:
                df[col] = 0
        x = df[cols]
    except AttributeError:
        x = df

    if x.empty:
        return pd.DataFrame(), np.array([])

    # 7. 스케일링 적용
    x_scaled = scaler.transform(x)
    x_final = pd.DataFrame(x_scaled, columns=x.columns)

    return x_final, y

# %% [markdown]
# - 점검: 다음 구문이 잘 수행되어 x_val, y_val이 분리되어야 합니다.

# %%
# x_val, y_val 나누기
x_val, y_val = build_model_input(new_test)

# 확인
print('x_val shape:', x_val.shape)
print('y_val shape:', y_val.shape)
# Out:
# x_val shape: (350, 78)
# y_val shape: (350,)

# %% [markdown]
# ## **3. 미션 9: 기본 모델로 예측 및 평가**

# %% [markdown]
# ### (1) 데이터 전처리
#
# - new_test 데이터프레임을 x_val, y_val로 분리합니다.

# %%
# 방법 2를 위한 데이터 준비 (new_train만 사용)
x_train_new_data, y_train_new_data = build_model_input(new_train)

# 검증 데이터는 모든 모델에서 동일하게 사용
x_val, y_val = build_model_input(new_test)

print('x_train_new_data shape:', x_train_new_data.shape, 'y_train_new_data shape:', y_train_new_data.shape)
print('x_val shape:', x_val.shape, 'y_val shape:', y_val.shape)
# Out:
# x_train_new_data shape: (850, 78) y_train_new_data shape: (850,)
# x_val shape: (350, 78) y_val shape: (350,)

# %% [markdown]
# ### 전처리 후 결측치 및 데이터 타입 확인

# %%
# x_train 결측치 확인
print(x_train.isnull().sum().sum())

# x_val 결측치 확인
print(x_val.isnull().sum().sum())
# Out:
# 0
# 0

# %%
x_train.info() # object 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 78 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               850 non-null    float64
#  1   Customer Type                        850 non-null    float64
#  2   Age                                  850 non-null    float64
#  3   Type of Travel                       850 non-null    float64
#  4   Class                                850 non-null    float64
#  5   Flight Distance                      850 non-null    float64
#  6   Departure Delay in Minutes           850 non-null    float64
#  7   Arrival Delay in Minutes             850 non-null    float64
#  8   Inflight wifi service_1              850 non-null    float64
#  9   Inflight wifi service_2              850 non-null    float64
#  10  Inflight wifi service_3              850 non-null    float64
#  11  Inflight wifi service_4              850 non-null    float64
#  12  Inflight wifi service_5              850 non-null    float64
#  13  Departure/Arrival time convenient_1  850 non-null    float64
#  14  Departure/Arrival time convenient_2  850 non-null    float64
#  15  Departure/Arrival time convenient_3  850 non-null    float64
#  16  Departure/Arrival time convenient_4  850 non-null    float64
#  17  Departure/Arrival time convenient_5  850 non-null    float64
#  18  Ease of Online booking_1             850 non-null    float64
#  19  Ease of Online booking_2             850 non-null    float64
#  20  Ease of Online booking_3             850 non-null    float64
#  21  Ease of Online booking_4             850 non-null    float64
#  22  Ease of Online booking_5             850 non-null    float64
#  23  Gate location_1                      850 non-null    float64
#  24  Gate location_2                      850 non-null    float64
#  25  Gate location_3                      850 non-null    float64
#  26  Gate location_4                      850 non-null    float64
#  27  Gate location_5                      850 non-null    float64
#  28  Food and drink_1                     850 non-null    float64
#  29  Food and drink_2                     850 non-null    float64
#  30  Food and drink_3                     850 non-null    float64
#  31  Food and drink_4                     850 non-null    float64
#  32  Food and drink_5                     850 non-null    float64
#  33  Online boarding_1                    850 non-null    float64
#  34  Online boarding_2                    850 non-null    float64
#  35  Online boarding_3                    850 non-null    float64
#  36  Online boarding_4                    850 non-null    float64
#  37  Online boarding_5                    850 non-null    float64
#  38  Seat comfort_1                       850 non-null    float64
#  39  Seat comfort_2                       850 non-null    float64
#  40  Seat comfort_3                       850 non-null    float64
#  41  Seat comfort_4                       850 non-null    float64
#  42  Seat comfort_5                       850 non-null    float64
#  43  Inflight entertainment_1             850 non-null    float64
#  44  Inflight entertainment_2             850 non-null    float64
#  45  Inflight entertainment_3             850 non-null    float64
#  46  Inflight entertainment_4             850 non-null    float64
#  47  Inflight entertainment_5             850 non-null    float64
#  48  On-board service_1                   850 non-null    float64
#  49  On-board service_2                   850 non-null    float64
#  50  On-board service_3                   850 non-null    float64
#  51  On-board service_4                   850 non-null    float64
#  52  On-board service_5                   850 non-null    float64
#  53  Leg room service_1                   850 non-null    float64
#  54  Leg room service_2                   850 non-null    float64
#  55  Leg room service_3                   850 non-null    float64
#  56  Leg room service_4                   850 non-null    float64
#  57  Leg room service_5                   850 non-null    float64
#  58  Baggage handling_1                   850 non-null    float64
#  59  Baggage handling_2                   850 non-null    float64
#  60  Baggage handling_3                   850 non-null    float64
#  61  Baggage handling_4                   850 non-null    float64
#  62  Baggage handling_5                   850 non-null    float64
#  63  Checkin service_1                    850 non-null    float64
#  64  Checkin service_2                    850 non-null    float64
#  65  Checkin service_3                    850 non-null    float64
#  66  Checkin service_4                    850 non-null    float64
#  67  Checkin service_5                    850 non-null    float64
#  68  Inflight service_1                   850 non-null    float64
#  69  Inflight service_2                   850 non-null    float64
#  70  Inflight service_3                   850 non-null    float64
#  71  Inflight service_4                   850 non-null    float64
#  72  Inflight service_5                   850 non-null    float64
#  73  Cleanliness_1                        850 non-null    float64
#  74  Cleanliness_2                        850 non-null    float64
#  75  Cleanliness_3                        850 non-null    float64
#  76  Cleanliness_4                        850 non-null    float64
#  77  Cleanliness_5                        850 non-null    float64
# dtypes: float64(78)
# memory usage: 518.1 KB

# %%
x_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 78 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               350 non-null    float64
#  1   Customer Type                        350 non-null    float64
#  2   Age                                  350 non-null    float64
#  3   Type of Travel                       350 non-null    float64
#  4   Class                                350 non-null    float64
#  5   Flight Distance                      350 non-null    float64
#  6   Departure Delay in Minutes           350 non-null    float64
#  7   Arrival Delay in Minutes             350 non-null    float64
#  8   Inflight wifi service_1              350 non-null    float64
#  9   Inflight wifi service_2              350 non-null    float64
#  10  Inflight wifi service_3              350 non-null    float64
#  11  Inflight wifi service_4              350 non-null    float64
#  12  Inflight wifi service_5              350 non-null    float64
#  13  Departure/Arrival time convenient_1  350 non-null    float64
#  14  Departure/Arrival time convenient_2  350 non-null    float64
#  15  Departure/Arrival time convenient_3  350 non-null    float64
#  16  Departure/Arrival time convenient_4  350 non-null    float64
#  17  Departure/Arrival time convenient_5  350 non-null    float64
#  18  Ease of Online booking_1             350 non-null    float64
#  19  Ease of Online booking_2             350 non-null    float64
#  20  Ease of Online booking_3             350 non-null    float64
#  21  Ease of Online booking_4             350 non-null    float64
#  22  Ease of Online booking_5             350 non-null    float64
#  23  Gate location_1                      350 non-null    float64
#  24  Gate location_2                      350 non-null    float64
#  25  Gate location_3                      350 non-null    float64
#  26  Gate location_4                      350 non-null    float64
#  27  Gate location_5                      350 non-null    float64
#  28  Food and drink_1                     350 non-null    float64
#  29  Food and drink_2                     350 non-null    float64
#  30  Food and drink_3                     350 non-null    float64
#  31  Food and drink_4                     350 non-null    float64
#  32  Food and drink_5                     350 non-null    float64
#  33  Online boarding_1                    350 non-null    float64
#  34  Online boarding_2                    350 non-null    float64
#  35  Online boarding_3                    350 non-null    float64
#  36  Online boarding_4                    350 non-null    float64
#  37  Online boarding_5                    350 non-null    float64
#  38  Seat comfort_1                       350 non-null    float64
#  39  Seat comfort_2                       350 non-null    float64
#  40  Seat comfort_3                       350 non-null    float64
#  41  Seat comfort_4                       350 non-null    float64
#  42  Seat comfort_5                       350 non-null    float64
#  43  Inflight entertainment_1             350 non-null    float64
#  44  Inflight entertainment_2             350 non-null    float64
#  45  Inflight entertainment_3             350 non-null    float64
#  46  Inflight entertainment_4             350 non-null    float64
#  47  Inflight entertainment_5             350 non-null    float64
#  48  On-board service_1                   350 non-null    float64
#  49  On-board service_2                   350 non-null    float64
#  50  On-board service_3                   350 non-null    float64
#  51  On-board service_4                   350 non-null    float64
#  52  On-board service_5                   350 non-null    float64
#  53  Leg room service_1                   350 non-null    float64
#  54  Leg room service_2                   350 non-null    float64
#  55  Leg room service_3                   350 non-null    float64
#  56  Leg room service_4                   350 non-null    float64
#  57  Leg room service_5                   350 non-null    float64
#  58  Baggage handling_1                   350 non-null    float64
#  59  Baggage handling_2                   350 non-null    float64
#  60  Baggage handling_3                   350 non-null    float64
#  61  Baggage handling_4                   350 non-null    float64
#  62  Baggage handling_5                   350 non-null    float64
#  63  Checkin service_1                    350 non-null    float64
#  64  Checkin service_2                    350 non-null    float64
#  65  Checkin service_3                    350 non-null    float64
#  66  Checkin service_4                    350 non-null    float64
#  67  Checkin service_5                    350 non-null    float64
#  68  Inflight service_1                   350 non-null    float64
#  69  Inflight service_2                   350 non-null    float64
#  70  Inflight service_3                   350 non-null    float64
#  71  Inflight service_4                   350 non-null    float64
#  72  Inflight service_5                   350 non-null    float64
#  73  Cleanliness_1                        350 non-null    float64
#  74  Cleanliness_2                        350 non-null    float64
#  75  Cleanliness_3                        350 non-null    float64
#  76  Cleanliness_4                        350 non-null    float64
#  77  Cleanliness_5                        350 non-null    float64
# dtypes: float64(78)
# memory usage: 213.4 KB

# %% [markdown]
# ### (2) 예측 및 평가
#
# - 새로운 데이터에 대한 예측과 평가를 수행합니다.

# %% [markdown]
# ## **4. 미션 10: 모델 추가 학습**

# %% [markdown]
# ### (1) 학습용 데이터 준비
#
# - **방법 1:** `original_df`, `new_train`, `new_test`를 합쳐 `x_combined_train`, `y_combined_train`을 준비합니다.
# - **방법 2:** `new_train` 데이터프레임을 `x_train_new_data`, `y_train_new_data`로 분리합니다. (위에서 이미 수행됨)

# %%
# 방법 1: original_df, new_train, new_test를 합친 데이터 준비
# 주의: original_df는 build_model_input 함수가 예상하는 '원시' 상태여야 합니다.
# 기존 original_df가 이미 전처리된 상태일 수 있으므로, 다시 로드하여 raw 상태로 사용합니다.
df_raw_original = pd.read_csv(path + 'data.csv')

# ID 컬럼을 제외한 모든 컬럼에 대해 결합 (Unnamed: 0은 build_model_input에서 처리됨)
# new_train과 new_test는 이미 로드된 상태이므로 그대로 사용
combined_raw_df = pd.concat([df_raw_original, new_train, new_test], ignore_index=True)

x_combined_train, y_combined_train = build_model_input(combined_raw_df)

# Combined data에 대한 클래스 가중치 계산
class_weights_combined = class_weight.compute_class_weight('balanced', classes=np.unique(y_combined_train), y=y_combined_train)
class_weight_dict_combined = dict(enumerate(class_weights_combined))

print('x_combined_train shape:', x_combined_train.shape)
print('y_combined_train shape:', y_combined_train.shape)
print('Class Weight Dictionary (Combined Data):', class_weight_dict_combined)

# 방법 2: new_train 데이터에 대한 클래스 가중치 계산 (model2, model3용)
class_weights_new_data = class_weight.compute_class_weight('balanced', classes=np.unique(y_train_new_data), y=y_train_new_data)
class_weight_dict_new_data = dict(enumerate(class_weights_new_data))

print('\nx_train_new_data shape:', x_train_new_data.shape)
print('y_train_new_data shape:', y_train_new_data.shape)
print('Class Weight Dictionary (New Data Only):', class_weight_dict_new_data)
# Out:
# x_combined_train shape: (1200, 78)
# y_combined_train shape: (1200,)
# Class Weight Dictionary (Combined Data): {0: np.float64(0.9174311926605505), 1: np.float64(1.098901098901099)}
#
# x_train_new_data shape: (850, 78)
# y_train_new_data shape: (850,)
# Class Weight Dictionary (New Data Only): {0: np.float64(0.91792656587473), 1: np.float64(1.0981912144702843)}

# %% [markdown]
# ### (2) 방법 1: 모델 초기화
#
# - 이전에 만들었던 성능이 좋았던 모델과 같은 모델을 만들어 학습 후 성능을 확인합니다.

# %%
# 방법 1: 모델 초기화 및 전체 데이터로 학습
clear_session()
nf = x_combined_train.shape[1] # 전체 데이터셋의 피처 수

model1 = Sequential([
    Input(shape=(nf, )),
    Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.4),
    Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.3),
    Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.4),
    Dense(4, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model1.summary()

# 학습 방법을 설정하고 학습을 수행합니다.
model1.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history1 = model1.fit(x_combined_train, y_combined_train, epochs=300, batch_size=32, validation_data=(x_val, y_val), callbacks=[es], verbose=1, class_weight=class_weight_dict_combined)

# 학습 곡선 확인
dl_history_plot(history1.history)

# 검증 데이터 평가
y_pred1 = model1.predict(x_val)
y_pred1 = (y_pred1 > 0.5).astype(int)

print(classification_report(y_val, y_pred1))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         2,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,233 (12.63 KB)
#  Trainable params: 3,233 (12.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 110ms/step - accuracy: 0.4717 - loss: 0.7955 - val_accuracy: 0.4714 - val_loss: 0.7786
# Epoch 2/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5033 - loss: 0.7855 - val_accuracy: 0.4829 - val_loss: 0.7770
# Epoch 3/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4942 - loss: 0.7845 - val_accuracy: 0.4886 - val_loss: 0.7759
# Epoch 4/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5075 - loss: 0.7817 - val_accuracy: 0.4971 - val_loss: 0.7747
# Epoch 5/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5042 - loss: 0.7871 - val_accuracy: 0.5029 - val_loss: 0.7736
# Epoch 6/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4992 - loss: 0.7820 - val_accuracy: 0.5000 - val_loss: 0.7727
# Epoch 7/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4950 - loss: 0.7835 - val_accuracy: 0.4943 - val_loss: 0.7717
# Epoch 8/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5025 - loss: 0.7826 - val_accuracy: 0.4971 - val_loss: 0.7709
# Epoch 9/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5117 - loss: 0.7764 - val_accuracy: 0.5000 - val_loss: 0.7702
# Epoch 10/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5167 - loss: 0.7771 - val_accuracy: 0.5086 - val_loss: 0.7694
# Epoch 11/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5050 - loss: 0.7734 - val_accuracy: 0.5114 - val_loss: 0.7687
# Epoch 12/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5208 - loss: 0.7668 - val_accuracy: 0.5086 - val_loss: 0.7681
# Epoch 13/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5383 - loss: 0.7661 - val_accuracy: 0.5200 - val_loss: 0.7675
# Epoch 14/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5317 - loss: 0.7689 - val_accuracy: 0.5057 - val_loss: 0.7669
# Epoch 15/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5092 - loss: 0.7702 - val_accuracy: 0.5029 - val_loss: 0.7663
# Epoch 16/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5133 - loss: 0.7675 - val_accuracy: 0.5114 - val_loss: 0.7657
# Epoch 17/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5267 - loss: 0.7653 - val_accuracy: 0.5086 - val_loss: 0.7651
# Epoch 18/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5225 - loss: 0.7672 - val_accuracy: 0.5143 - val_loss: 0.7646
# Epoch 19/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5292 - loss: 0.7622 - val_accuracy: 0.5171 - val_loss: 0.7640
# Epoch 20/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5025 - loss: 0.7653 - val_accuracy: 0.5286 - val_loss: 0.7633
# Epoch 21/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5283 - loss: 0.7627 - val_accuracy: 0.5257 - val_loss: 0.7628
# Epoch 22/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5275 - loss: 0.7667 - val_accuracy: 0.5286 - val_loss: 0.7623
# Epoch 23/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5425 - loss: 0.7597 - val_accuracy: 0.5343 - val_loss: 0.7618
# Epoch 24/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5150 - loss: 0.7650 - val_accuracy: 0.5400 - val_loss: 0.7612
# Epoch 25/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5225 - loss: 0.7593 - val_accuracy: 0.5457 - val_loss: 0.7607
# Epoch 26/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5333 - loss: 0.7617 - val_accuracy: 0.5429 - val_loss: 0.7602
# Epoch 27/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5242 - loss: 0.7608 - val_accuracy: 0.5429 - val_loss: 0.7596
# Epoch 28/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5083 - loss: 0.7611 - val_accuracy: 0.5457 - val_loss: 0.7591
# Epoch 29/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5208 - loss: 0.7580 - val_accuracy: 0.5429 - val_loss: 0.7586
# Epoch 30/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5300 - loss: 0.7602 - val_accuracy: 0.5543 - val_loss: 0.7581
# Epoch 31/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5375 - loss: 0.7566 - val_accuracy: 0.5486 - val_loss: 0.7576
# Epoch 32/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5317 - loss: 0.7571 - val_accuracy: 0.5514 - val_loss: 0.7569
# Epoch 33/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5425 - loss: 0.7545 - val_accuracy: 0.5514 - val_loss: 0.7563
# Epoch 34/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5233 - loss: 0.7551 - val_accuracy: 0.5600 - val_loss: 0.7558
# Epoch 35/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5258 - loss: 0.7531 - val_accuracy: 0.5514 - val_loss: 0.7552
# Epoch 36/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5283 - loss: 0.7537 - val_accuracy: 0.5514 - val_loss: 0.7547
# Epoch 37/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5200 - loss: 0.7592 - val_accuracy: 0.5571 - val_loss: 0.7542
# Epoch 38/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5267 - loss: 0.7544 - val_accuracy: 0.5629 - val_loss: 0.7536
# Epoch 39/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5492 - loss: 0.7511 - val_accuracy: 0.5571 - val_loss: 0.7529
# Epoch 40/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5367 - loss: 0.7466 - val_accuracy: 0.5629 - val_loss: 0.7525
# Epoch 41/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5258 - loss: 0.7539 - val_accuracy: 0.5629 - val_loss: 0.7517
# Epoch 42/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5342 - loss: 0.7482 - val_accuracy: 0.5771 - val_loss: 0.7509
# Epoch 43/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5417 - loss: 0.7470 - val_accuracy: 0.5829 - val_loss: 0.7500
# Epoch 44/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5542 - loss: 0.7466 - val_accuracy: 0.5943 - val_loss: 0.7490
# Epoch 45/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5317 - loss: 0.7489 - val_accuracy: 0.5914 - val_loss: 0.7479
# Epoch 46/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5533 - loss: 0.7476 - val_accuracy: 0.6029 - val_loss: 0.7471
# Epoch 47/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5492 - loss: 0.7462 - val_accuracy: 0.6143 - val_loss: 0.7458
# Epoch 48/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5292 - loss: 0.7488 - val_accuracy: 0.6314 - val_loss: 0.7446
# Epoch 49/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5525 - loss: 0.7434 - val_accuracy: 0.6429 - val_loss: 0.7437
# Epoch 50/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5442 - loss: 0.7426 - val_accuracy: 0.6543 - val_loss: 0.7424
# Epoch 51/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5633 - loss: 0.7414 - val_accuracy: 0.6657 - val_loss: 0.7413
# Epoch 52/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5750 - loss: 0.7405 - val_accuracy: 0.6971 - val_loss: 0.7388
# Epoch 53/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5650 - loss: 0.7404 - val_accuracy: 0.7171 - val_loss: 0.7371
# Epoch 54/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5608 - loss: 0.7390 - val_accuracy: 0.7429 - val_loss: 0.7343
# Epoch 55/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5850 - loss: 0.7358 - val_accuracy: 0.7686 - val_loss: 0.7316
# Epoch 56/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5575 - loss: 0.7355 - val_accuracy: 0.7800 - val_loss: 0.7291
# Epoch 57/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5700 - loss: 0.7329 - val_accuracy: 0.7771 - val_loss: 0.7270
# Epoch 58/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5658 - loss: 0.7320 - val_accuracy: 0.7829 - val_loss: 0.7244
# Epoch 59/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5675 - loss: 0.7310 - val_accuracy: 0.7943 - val_loss: 0.7211
# Epoch 60/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6000 - loss: 0.7277 - val_accuracy: 0.7914 - val_loss: 0.7171
# Epoch 61/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5808 - loss: 0.7291 - val_accuracy: 0.7914 - val_loss: 0.7147
# Epoch 62/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5758 - loss: 0.7278 - val_accuracy: 0.7943 - val_loss: 0.7117
# Epoch 63/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5825 - loss: 0.7221 - val_accuracy: 0.7971 - val_loss: 0.7078
# Epoch 64/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5667 - loss: 0.7264 - val_accuracy: 0.7943 - val_loss: 0.7040
# Epoch 65/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5933 - loss: 0.7129 - val_accuracy: 0.7886 - val_loss: 0.6987
# Epoch 66/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5933 - loss: 0.7167 - val_accuracy: 0.7943 - val_loss: 0.6945
# Epoch 67/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5975 - loss: 0.7115 - val_accuracy: 0.7971 - val_loss: 0.6903
# Epoch 68/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5833 - loss: 0.7183 - val_accuracy: 0.8000 - val_loss: 0.6865
# Epoch 69/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6075 - loss: 0.7170 - val_accuracy: 0.8086 - val_loss: 0.6826
# Epoch 70/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6175 - loss: 0.6978 - val_accuracy: 0.8143 - val_loss: 0.6777
# Epoch 71/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6042 - loss: 0.7100 - val_accuracy: 0.8200 - val_loss: 0.6733
# Epoch 72/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5917 - loss: 0.7055 - val_accuracy: 0.8143 - val_loss: 0.6688
# Epoch 73/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6267 - loss: 0.6914 - val_accuracy: 0.8143 - val_loss: 0.6627
# Epoch 74/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6100 - loss: 0.7002 - val_accuracy: 0.8171 - val_loss: 0.6581
# Epoch 75/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6000 - loss: 0.6944 - val_accuracy: 0.8171 - val_loss: 0.6529
# Epoch 76/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6083 - loss: 0.6798 - val_accuracy: 0.8200 - val_loss: 0.6479
# Epoch 77/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6600 - loss: 0.6738 - val_accuracy: 0.8229 - val_loss: 0.6409
# Epoch 78/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6467 - loss: 0.6750 - val_accuracy: 0.8229 - val_loss: 0.6345
# Epoch 79/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6350 - loss: 0.6768 - val_accuracy: 0.8257 - val_loss: 0.6289
# Epoch 80/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6567 - loss: 0.6733 - val_accuracy: 0.8257 - val_loss: 0.6247
# Epoch 81/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6492 - loss: 0.6745 - val_accuracy: 0.8257 - val_loss: 0.6212
# Epoch 82/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6642 - loss: 0.6620 - val_accuracy: 0.8314 - val_loss: 0.6163
# Epoch 83/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6392 - loss: 0.6623 - val_accuracy: 0.8229 - val_loss: 0.6105
# Epoch 84/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6825 - loss: 0.6371 - val_accuracy: 0.8229 - val_loss: 0.6041
# Epoch 85/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6500 - loss: 0.6633 - val_accuracy: 0.8229 - val_loss: 0.5992
# Epoch 86/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6692 - loss: 0.6611 - val_accuracy: 0.8200 - val_loss: 0.5949
# Epoch 87/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6617 - loss: 0.6479 - val_accuracy: 0.8257 - val_loss: 0.5912
# Epoch 88/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6625 - loss: 0.6422 - val_accuracy: 0.8400 - val_loss: 0.5859
# Epoch 89/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6783 - loss: 0.6446 - val_accuracy: 0.8343 - val_loss: 0.5818
# Epoch 90/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6550 - loss: 0.6493 - val_accuracy: 0.8257 - val_loss: 0.5778
# Epoch 91/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6642 - loss: 0.6438 - val_accuracy: 0.8286 - val_loss: 0.5740
# Epoch 92/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7000 - loss: 0.6338 - val_accuracy: 0.8229 - val_loss: 0.5704
# Epoch 93/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6592 - loss: 0.6485 - val_accuracy: 0.8286 - val_loss: 0.5673
# Epoch 94/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6758 - loss: 0.6399 - val_accuracy: 0.8286 - val_loss: 0.5645
# Epoch 95/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6950 - loss: 0.6283 - val_accuracy: 0.8286 - val_loss: 0.5608
# Epoch 96/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6883 - loss: 0.6261 - val_accuracy: 0.8314 - val_loss: 0.5576
# Epoch 97/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6842 - loss: 0.6130 - val_accuracy: 0.8314 - val_loss: 0.5529
# Epoch 98/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6900 - loss: 0.6208 - val_accuracy: 0.8314 - val_loss: 0.5488
# Epoch 99/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6883 - loss: 0.6155 - val_accuracy: 0.8343 - val_loss: 0.5453
# Epoch 100/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6842 - loss: 0.6207 - val_accuracy: 0.8286 - val_loss: 0.5422
# Epoch 101/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6942 - loss: 0.6080 - val_accuracy: 0.8314 - val_loss: 0.5385
# Epoch 102/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6933 - loss: 0.6341 - val_accuracy: 0.8343 - val_loss: 0.5352
# Epoch 103/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6858 - loss: 0.6083 - val_accuracy: 0.8343 - val_loss: 0.5327
# Epoch 104/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6792 - loss: 0.6297 - val_accuracy: 0.8286 - val_loss: 0.5309
# Epoch 105/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6975 - loss: 0.6197 - val_accuracy: 0.8343 - val_loss: 0.5287
# Epoch 106/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7175 - loss: 0.6036 - val_accuracy: 0.8343 - val_loss: 0.5259
# Epoch 107/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6958 - loss: 0.6251 - val_accuracy: 0.8400 - val_loss: 0.5246
# Epoch 108/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7075 - loss: 0.6007 - val_accuracy: 0.8400 - val_loss: 0.5211
# Epoch 109/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7450 - loss: 0.5919 - val_accuracy: 0.8343 - val_loss: 0.5185
# Epoch 110/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6975 - loss: 0.6061 - val_accuracy: 0.8371 - val_loss: 0.5162
# Epoch 111/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7392 - loss: 0.5827 - val_accuracy: 0.8429 - val_loss: 0.5127
# Epoch 112/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7217 - loss: 0.6014 - val_accuracy: 0.8514 - val_loss: 0.5112
# Epoch 113/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7283 - loss: 0.5825 - val_accuracy: 0.8543 - val_loss: 0.5092
# Epoch 114/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7125 - loss: 0.6010 - val_accuracy: 0.8514 - val_loss: 0.5060
# Epoch 115/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7383 - loss: 0.5783 - val_accuracy: 0.8514 - val_loss: 0.5029
# Epoch 116/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7367 - loss: 0.5713 - val_accuracy: 0.8400 - val_loss: 0.5000
# Epoch 117/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7492 - loss: 0.5900 - val_accuracy: 0.8429 - val_loss: 0.4984
# Epoch 118/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7325 - loss: 0.5771 - val_accuracy: 0.8514 - val_loss: 0.4956
# Epoch 119/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7475 - loss: 0.5712 - val_accuracy: 0.8486 - val_loss: 0.4927
# Epoch 120/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7342 - loss: 0.5794 - val_accuracy: 0.8514 - val_loss: 0.4913
# Epoch 121/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7325 - loss: 0.5880 - val_accuracy: 0.8486 - val_loss: 0.4892
# Epoch 122/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7542 - loss: 0.5711 - val_accuracy: 0.8486 - val_loss: 0.4872
# Epoch 123/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7267 - loss: 0.5928 - val_accuracy: 0.8457 - val_loss: 0.4852
# Epoch 124/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7675 - loss: 0.5719 - val_accuracy: 0.8457 - val_loss: 0.4834
# Epoch 125/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7525 - loss: 0.5622 - val_accuracy: 0.8457 - val_loss: 0.4795
# Epoch 126/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7275 - loss: 0.5916 - val_accuracy: 0.8457 - val_loss: 0.4781
# Epoch 127/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7550 - loss: 0.5718 - val_accuracy: 0.8514 - val_loss: 0.4758
# Epoch 128/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7442 - loss: 0.5736 - val_accuracy: 0.8457 - val_loss: 0.4736
# Epoch 129/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7550 - loss: 0.5706 - val_accuracy: 0.8486 - val_loss: 0.4709
# Epoch 130/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7625 - loss: 0.5657 - val_accuracy: 0.8486 - val_loss: 0.4685
# Epoch 131/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7692 - loss: 0.5450 - val_accuracy: 0.8514 - val_loss: 0.4655
# Epoch 132/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7633 - loss: 0.5627 - val_accuracy: 0.8543 - val_loss: 0.4636
# Epoch 133/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7650 - loss: 0.5688 - val_accuracy: 0.8514 - val_loss: 0.4611
# Epoch 134/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7683 - loss: 0.5562 - val_accuracy: 0.8514 - val_loss: 0.4581
# Epoch 135/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7717 - loss: 0.5468 - val_accuracy: 0.8543 - val_loss: 0.4556
# Epoch 136/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7775 - loss: 0.5499 - val_accuracy: 0.8571 - val_loss: 0.4536
# Epoch 137/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7817 - loss: 0.5398 - val_accuracy: 0.8514 - val_loss: 0.4506
# Epoch 138/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7683 - loss: 0.5479 - val_accuracy: 0.8543 - val_loss: 0.4489
# Epoch 139/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7725 - loss: 0.5345 - val_accuracy: 0.8571 - val_loss: 0.4468
# Epoch 140/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7733 - loss: 0.5337 - val_accuracy: 0.8629 - val_loss: 0.4445
# Epoch 141/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7742 - loss: 0.5438 - val_accuracy: 0.8571 - val_loss: 0.4418
# Epoch 142/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7858 - loss: 0.5227 - val_accuracy: 0.8600 - val_loss: 0.4387
# Epoch 143/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7900 - loss: 0.5298 - val_accuracy: 0.8600 - val_loss: 0.4367
# Epoch 144/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7983 - loss: 0.5266 - val_accuracy: 0.8600 - val_loss: 0.4347
# Epoch 145/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7775 - loss: 0.5535 - val_accuracy: 0.8629 - val_loss: 0.4324
# Epoch 146/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7883 - loss: 0.5424 - val_accuracy: 0.8600 - val_loss: 0.4313
# Epoch 147/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7900 - loss: 0.5371 - val_accuracy: 0.8629 - val_loss: 0.4306
# Epoch 148/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7892 - loss: 0.5301 - val_accuracy: 0.8600 - val_loss: 0.4301
# Epoch 149/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7850 - loss: 0.5212 - val_accuracy: 0.8657 - val_loss: 0.4276
# Epoch 150/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7708 - loss: 0.5587 - val_accuracy: 0.8629 - val_loss: 0.4274
# Epoch 151/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7850 - loss: 0.5328 - val_accuracy: 0.8600 - val_loss: 0.4264
# Epoch 152/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7875 - loss: 0.5299 - val_accuracy: 0.8686 - val_loss: 0.4247
# Epoch 153/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7983 - loss: 0.5247 - val_accuracy: 0.8714 - val_loss: 0.4231
# Epoch 154/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7875 - loss: 0.5312 - val_accuracy: 0.8714 - val_loss: 0.4224
# Epoch 155/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7958 - loss: 0.5262 - val_accuracy: 0.8686 - val_loss: 0.4218
# Epoch 156/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7758 - loss: 0.5288 - val_accuracy: 0.8714 - val_loss: 0.4198
# Epoch 157/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7950 - loss: 0.5268 - val_accuracy: 0.8714 - val_loss: 0.4190
# Epoch 158/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8042 - loss: 0.5165 - val_accuracy: 0.8714 - val_loss: 0.4169
# Epoch 159/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8008 - loss: 0.5128 - val_accuracy: 0.8743 - val_loss: 0.4153
# Epoch 160/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8008 - loss: 0.5324 - val_accuracy: 0.8771 - val_loss: 0.4139
# Epoch 161/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8025 - loss: 0.5187 - val_accuracy: 0.8714 - val_loss: 0.4119
# Epoch 162/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8008 - loss: 0.5301 - val_accuracy: 0.8800 - val_loss: 0.4114
# Epoch 163/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8108 - loss: 0.5238 - val_accuracy: 0.8800 - val_loss: 0.4107
# Epoch 164/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8017 - loss: 0.5328 - val_accuracy: 0.8771 - val_loss: 0.4092
# Epoch 165/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8058 - loss: 0.5024 - val_accuracy: 0.8771 - val_loss: 0.4073
# Epoch 166/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8050 - loss: 0.5187 - val_accuracy: 0.8771 - val_loss: 0.4057
# Epoch 167/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7975 - loss: 0.5187 - val_accuracy: 0.8800 - val_loss: 0.4044
# Epoch 168/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7900 - loss: 0.5262 - val_accuracy: 0.8771 - val_loss: 0.4039
# Epoch 169/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8133 - loss: 0.5215 - val_accuracy: 0.8800 - val_loss: 0.4028
# Epoch 170/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7967 - loss: 0.5347 - val_accuracy: 0.8800 - val_loss: 0.4023
# Epoch 171/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7858 - loss: 0.5165 - val_accuracy: 0.8857 - val_loss: 0.4021
# Epoch 172/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7992 - loss: 0.5213 - val_accuracy: 0.8886 - val_loss: 0.4019
# Epoch 173/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8092 - loss: 0.5246 - val_accuracy: 0.8857 - val_loss: 0.4010
# Epoch 174/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8117 - loss: 0.5125 - val_accuracy: 0.8886 - val_loss: 0.3997
# Epoch 175/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7883 - loss: 0.5111 - val_accuracy: 0.8914 - val_loss: 0.3986
# Epoch 176/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8175 - loss: 0.5051 - val_accuracy: 0.8914 - val_loss: 0.3972
# Epoch 177/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7925 - loss: 0.5217 - val_accuracy: 0.8914 - val_loss: 0.3969
# Epoch 178/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8142 - loss: 0.4947 - val_accuracy: 0.8857 - val_loss: 0.3960
# Epoch 179/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8183 - loss: 0.4697 - val_accuracy: 0.8829 - val_loss: 0.3939
# Epoch 180/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8208 - loss: 0.4898 - val_accuracy: 0.8914 - val_loss: 0.3924
# Epoch 181/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8117 - loss: 0.4923 - val_accuracy: 0.8914 - val_loss: 0.3911
# Epoch 182/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8292 - loss: 0.4914 - val_accuracy: 0.8943 - val_loss: 0.3892
# Epoch 183/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8050 - loss: 0.4914 - val_accuracy: 0.8857 - val_loss: 0.3885
# Epoch 184/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8217 - loss: 0.4867 - val_accuracy: 0.8857 - val_loss: 0.3864
# Epoch 185/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8000 - loss: 0.5264 - val_accuracy: 0.8857 - val_loss: 0.3862
# Epoch 186/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8183 - loss: 0.4860 - val_accuracy: 0.8857 - val_loss: 0.3852
# Epoch 187/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8108 - loss: 0.5081 - val_accuracy: 0.8857 - val_loss: 0.3851
# Epoch 188/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8242 - loss: 0.4951 - val_accuracy: 0.8886 - val_loss: 0.3847
# Epoch 189/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.4777 - val_accuracy: 0.8943 - val_loss: 0.3834
# Epoch 190/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8117 - loss: 0.4910 - val_accuracy: 0.8914 - val_loss: 0.3829
# Epoch 191/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8300 - loss: 0.4754 - val_accuracy: 0.8914 - val_loss: 0.3813
# Epoch 192/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8167 - loss: 0.4889 - val_accuracy: 0.8914 - val_loss: 0.3794
# Epoch 193/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8233 - loss: 0.4758 - val_accuracy: 0.8914 - val_loss: 0.3798
# Epoch 194/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8300 - loss: 0.4736 - val_accuracy: 0.8914 - val_loss: 0.3780
# Epoch 195/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8158 - loss: 0.4877 - val_accuracy: 0.8914 - val_loss: 0.3767
# Epoch 196/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8342 - loss: 0.4661 - val_accuracy: 0.8943 - val_loss: 0.3762
# Epoch 197/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8267 - loss: 0.4902 - val_accuracy: 0.8943 - val_loss: 0.3762
# Epoch 198/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8092 - loss: 0.4778 - val_accuracy: 0.8943 - val_loss: 0.3746
# Epoch 199/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8192 - loss: 0.4805 - val_accuracy: 0.8943 - val_loss: 0.3732
# Epoch 200/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8375 - loss: 0.4629 - val_accuracy: 0.8943 - val_loss: 0.3716
# Epoch 201/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8450 - loss: 0.4833 - val_accuracy: 0.8943 - val_loss: 0.3722
# Epoch 202/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8425 - loss: 0.4746 - val_accuracy: 0.8886 - val_loss: 0.3725
# Epoch 203/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7900 - loss: 0.5073 - val_accuracy: 0.8971 - val_loss: 0.3708
# Epoch 204/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8267 - loss: 0.4706 - val_accuracy: 0.8971 - val_loss: 0.3695
# Epoch 205/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8133 - loss: 0.4853 - val_accuracy: 0.9000 - val_loss: 0.3684
# Epoch 206/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8292 - loss: 0.4898 - val_accuracy: 0.8943 - val_loss: 0.3665
# Epoch 207/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8308 - loss: 0.4780 - val_accuracy: 0.8943 - val_loss: 0.3664
# Epoch 208/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8183 - loss: 0.4882 - val_accuracy: 0.8971 - val_loss: 0.3661
# Epoch 209/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8267 - loss: 0.4838 - val_accuracy: 0.8971 - val_loss: 0.3648
# Epoch 210/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8300 - loss: 0.4769 - val_accuracy: 0.9000 - val_loss: 0.3642
# Epoch 211/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8400 - loss: 0.4611 - val_accuracy: 0.9000 - val_loss: 0.3626
# Epoch 212/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8183 - loss: 0.4708 - val_accuracy: 0.8971 - val_loss: 0.3620
# Epoch 213/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.4663 - val_accuracy: 0.8971 - val_loss: 0.3607
# Epoch 214/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8300 - loss: 0.4650 - val_accuracy: 0.8971 - val_loss: 0.3592
# Epoch 215/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8267 - loss: 0.4761 - val_accuracy: 0.8971 - val_loss: 0.3580
# Epoch 216/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8367 - loss: 0.4800 - val_accuracy: 0.9000 - val_loss: 0.3577
# Epoch 217/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8275 - loss: 0.4795 - val_accuracy: 0.9000 - val_loss: 0.3577
# Epoch 218/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8358 - loss: 0.4678 - val_accuracy: 0.9000 - val_loss: 0.3573
# Epoch 219/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8350 - loss: 0.4572 - val_accuracy: 0.9000 - val_loss: 0.3571
# Epoch 220/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8292 - loss: 0.4573 - val_accuracy: 0.9029 - val_loss: 0.3555
# Epoch 221/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8317 - loss: 0.4809 - val_accuracy: 0.9057 - val_loss: 0.3551
# Epoch 222/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8367 - loss: 0.4513 - val_accuracy: 0.9029 - val_loss: 0.3533
# Epoch 223/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8383 - loss: 0.4769 - val_accuracy: 0.9057 - val_loss: 0.3537
# Epoch 224/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8233 - loss: 0.4906 - val_accuracy: 0.9029 - val_loss: 0.3532
# Epoch 225/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8425 - loss: 0.4683 - val_accuracy: 0.9029 - val_loss: 0.3534
# Epoch 226/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8375 - loss: 0.4638 - val_accuracy: 0.9057 - val_loss: 0.3530
# Epoch 227/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8242 - loss: 0.4749 - val_accuracy: 0.9057 - val_loss: 0.3521
# Epoch 228/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8258 - loss: 0.4789 - val_accuracy: 0.9029 - val_loss: 0.3516
# Epoch 229/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8375 - loss: 0.4709 - val_accuracy: 0.9029 - val_loss: 0.3505
# Epoch 230/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8225 - loss: 0.4852 - val_accuracy: 0.9029 - val_loss: 0.3499
# Epoch 231/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8342 - loss: 0.4692 - val_accuracy: 0.8943 - val_loss: 0.3493
# Epoch 232/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8242 - loss: 0.4593 - val_accuracy: 0.8943 - val_loss: 0.3479
# Epoch 233/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8233 - loss: 0.4651 - val_accuracy: 0.8971 - val_loss: 0.3469
# Epoch 234/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8208 - loss: 0.4775 - val_accuracy: 0.8914 - val_loss: 0.3462
# Epoch 235/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8267 - loss: 0.4597 - val_accuracy: 0.9000 - val_loss: 0.3453
# Epoch 236/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8400 - loss: 0.4600 - val_accuracy: 0.9029 - val_loss: 0.3445
# Epoch 237/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8175 - loss: 0.4708 - val_accuracy: 0.9000 - val_loss: 0.3442
# Epoch 238/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8300 - loss: 0.4539 - val_accuracy: 0.8971 - val_loss: 0.3438
# Epoch 239/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8292 - loss: 0.4557 - val_accuracy: 0.8971 - val_loss: 0.3434
# Epoch 240/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.4550 - val_accuracy: 0.8971 - val_loss: 0.3418
# Epoch 241/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8400 - loss: 0.4585 - val_accuracy: 0.8971 - val_loss: 0.3415
# Epoch 242/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8342 - loss: 0.4692 - val_accuracy: 0.8971 - val_loss: 0.3408
# Epoch 243/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8350 - loss: 0.4597 - val_accuracy: 0.8971 - val_loss: 0.3405
# Epoch 244/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8483 - loss: 0.4589 - val_accuracy: 0.8943 - val_loss: 0.3401
# Epoch 245/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8383 - loss: 0.4593 - val_accuracy: 0.9000 - val_loss: 0.3392
# Epoch 246/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.4570 - val_accuracy: 0.9000 - val_loss: 0.3384
# Epoch 247/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8308 - loss: 0.4527 - val_accuracy: 0.9029 - val_loss: 0.3377
# Epoch 248/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8483 - loss: 0.4421 - val_accuracy: 0.8971 - val_loss: 0.3371
# Epoch 249/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8500 - loss: 0.4666 - val_accuracy: 0.8971 - val_loss: 0.3368
# Epoch 250/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8283 - loss: 0.4423 - val_accuracy: 0.8971 - val_loss: 0.3356
# Epoch 251/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8308 - loss: 0.4334 - val_accuracy: 0.9000 - val_loss: 0.3344
# Epoch 252/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8483 - loss: 0.4406 - val_accuracy: 0.8971 - val_loss: 0.3338
# Epoch 253/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8542 - loss: 0.4422 - val_accuracy: 0.8943 - val_loss: 0.3340
# Epoch 254/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8500 - loss: 0.4306 - val_accuracy: 0.8943 - val_loss: 0.3334
# Epoch 255/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8375 - loss: 0.4452 - val_accuracy: 0.8943 - val_loss: 0.3320
# Epoch 256/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8333 - loss: 0.4397 - val_accuracy: 0.8971 - val_loss: 0.3306
# Epoch 257/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8333 - loss: 0.4551 - val_accuracy: 0.9029 - val_loss: 0.3303
# Epoch 258/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8392 - loss: 0.4389 - val_accuracy: 0.9029 - val_loss: 0.3301
# Epoch 259/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8525 - loss: 0.4329 - val_accuracy: 0.9000 - val_loss: 0.3298
# Epoch 260/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8350 - loss: 0.4409 - val_accuracy: 0.9000 - val_loss: 0.3284
# Epoch 261/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8575 - loss: 0.4292 - val_accuracy: 0.8943 - val_loss: 0.3280
# Epoch 262/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8467 - loss: 0.4494 - val_accuracy: 0.8943 - val_loss: 0.3279
# Epoch 263/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8433 - loss: 0.4438 - val_accuracy: 0.9029 - val_loss: 0.3272
# Epoch 264/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8342 - loss: 0.4440 - val_accuracy: 0.9029 - val_loss: 0.3271
# Epoch 265/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8408 - loss: 0.4495 - val_accuracy: 0.9000 - val_loss: 0.3273
# Epoch 266/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8483 - loss: 0.4165 - val_accuracy: 0.8943 - val_loss: 0.3266
# Epoch 267/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8475 - loss: 0.4673 - val_accuracy: 0.9029 - val_loss: 0.3267
# Epoch 268/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8417 - loss: 0.4433 - val_accuracy: 0.9057 - val_loss: 0.3261
# Epoch 269/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8392 - loss: 0.4344 - val_accuracy: 0.9057 - val_loss: 0.3254
# Epoch 270/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8433 - loss: 0.4426 - val_accuracy: 0.9057 - val_loss: 0.3240
# Epoch 271/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8500 - loss: 0.4323 - val_accuracy: 0.9057 - val_loss: 0.3228
# Epoch 272/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8517 - loss: 0.4264 - val_accuracy: 0.9029 - val_loss: 0.3216
# Epoch 273/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8458 - loss: 0.4552 - val_accuracy: 0.9029 - val_loss: 0.3220
# Epoch 274/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8425 - loss: 0.4359 - val_accuracy: 0.9029 - val_loss: 0.3217
# Epoch 275/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8475 - loss: 0.4434 - val_accuracy: 0.9029 - val_loss: 0.3216
# Epoch 276/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8408 - loss: 0.4297 - val_accuracy: 0.9029 - val_loss: 0.3210
# Epoch 277/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8533 - loss: 0.4194 - val_accuracy: 0.9029 - val_loss: 0.3203
# Epoch 278/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8350 - loss: 0.4537 - val_accuracy: 0.9029 - val_loss: 0.3193
# Epoch 279/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.4449 - val_accuracy: 0.9086 - val_loss: 0.3183
# Epoch 280/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8367 - loss: 0.4262 - val_accuracy: 0.9086 - val_loss: 0.3178
# Epoch 281/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8492 - loss: 0.4390 - val_accuracy: 0.9086 - val_loss: 0.3168
# Epoch 282/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8633 - loss: 0.4274 - val_accuracy: 0.9086 - val_loss: 0.3174
# Epoch 283/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8617 - loss: 0.4357 - val_accuracy: 0.9029 - val_loss: 0.3179
# Epoch 284/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8550 - loss: 0.4100 - val_accuracy: 0.9029 - val_loss: 0.3176
# Epoch 285/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8525 - loss: 0.4200 - val_accuracy: 0.9086 - val_loss: 0.3155
# Epoch 286/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8400 - loss: 0.4574 - val_accuracy: 0.9086 - val_loss: 0.3158
# Epoch 287/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8417 - loss: 0.4519 - val_accuracy: 0.9057 - val_loss: 0.3157
# Epoch 288/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8475 - loss: 0.4332 - val_accuracy: 0.9057 - val_loss: 0.3144
# Epoch 289/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8608 - loss: 0.4226 - val_accuracy: 0.9057 - val_loss: 0.3133
# Epoch 290/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8542 - loss: 0.4162 - val_accuracy: 0.9086 - val_loss: 0.3115
# Epoch 291/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8525 - loss: 0.4261 - val_accuracy: 0.9086 - val_loss: 0.3109
# Epoch 292/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8458 - loss: 0.4206 - val_accuracy: 0.9086 - val_loss: 0.3097
# Epoch 293/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8492 - loss: 0.4225 - val_accuracy: 0.9057 - val_loss: 0.3096
# Epoch 294/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8667 - loss: 0.4089 - val_accuracy: 0.9057 - val_loss: 0.3092
# Epoch 295/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8500 - loss: 0.4273 - val_accuracy: 0.9143 - val_loss: 0.3082
# Epoch 296/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8517 - loss: 0.4301 - val_accuracy: 0.9086 - val_loss: 0.3069
# Epoch 297/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8425 - loss: 0.4401 - val_accuracy: 0.9114 - val_loss: 0.3066
# Epoch 298/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8550 - loss: 0.4337 - val_accuracy: 0.9143 - val_loss: 0.3062
# Epoch 299/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8450 - loss: 0.4237 - val_accuracy: 0.9086 - val_loss: 0.3067
# Epoch 300/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8550 - loss: 0.4242 - val_accuracy: 0.9143 - val_loss: 0.3060
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       191
#            1       0.91      0.91      0.91       159
#
#     accuracy                           0.91       350
#    macro avg       0.91      0.91      0.91       350
# weighted avg       0.91      0.91      0.91       350

# %% [markdown]
# ### (3) 방법 2: 추가 학습
#
# - 기본 모델을 기반으로 모델을 선언하고 추가 학습 후 성능을 확인합니다.

# %%
# 방법 2: 기본 모델에 추가 학습
model2 = load_model(path + 'base_model.keras')
model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         2,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,701 (37.90 KB)
#  Trainable params: 3,233 (12.63 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6,468 (25.27 KB)

# %% [markdown]
# - 학습 방법을 설정하고 학습을 수행합니다.

# %%
# 방법 2: 기본 모델 불러와 이어 학습 (Continued Training) - new_train 데이터만 사용

es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model2.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
history2 = model2.fit(x_train_new_data, y_train_new_data, epochs=300, batch_size=32, validation_data=(x_val, y_val), callbacks=[es], verbose=1, class_weight=class_weight_dict_new_data)
# Out:
# Epoch 1/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 140ms/step - accuracy: 0.5953 - loss: 0.9904 - val_accuracy: 0.6114 - val_loss: 1.0152
# Epoch 2/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6224 - loss: 0.9099 - val_accuracy: 0.6314 - val_loss: 0.9688
# Epoch 3/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6329 - loss: 0.8830 - val_accuracy: 0.6400 - val_loss: 0.9247
# Epoch 4/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6518 - loss: 0.8446 - val_accuracy: 0.6514 - val_loss: 0.8797
# Epoch 5/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6800 - loss: 0.7989 - val_accuracy: 0.6657 - val_loss: 0.8412
# Epoch 6/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6871 - loss: 0.7792 - val_accuracy: 0.6714 - val_loss: 0.8044
# Epoch 7/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6671 - loss: 0.7645 - val_accuracy: 0.6829 - val_loss: 0.7692
# Epoch 8/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7212 - loss: 0.6623 - val_accuracy: 0.7029 - val_loss: 0.7365
# Epoch 9/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7294 - loss: 0.6596 - val_accuracy: 0.7114 - val_loss: 0.7091
# Epoch 10/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7376 - loss: 0.6446 - val_accuracy: 0.7200 - val_loss: 0.6808
# Epoch 11/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7576 - loss: 0.6184 - val_accuracy: 0.7400 - val_loss: 0.6523
# Epoch 12/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7212 - loss: 0.6690 - val_accuracy: 0.7514 - val_loss: 0.6261
# Epoch 13/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7612 - loss: 0.5808 - val_accuracy: 0.7571 - val_loss: 0.6040
# Epoch 14/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7647 - loss: 0.5770 - val_accuracy: 0.7714 - val_loss: 0.5866
# Epoch 15/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7565 - loss: 0.5971 - val_accuracy: 0.7771 - val_loss: 0.5716
# Epoch 16/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7576 - loss: 0.5847 - val_accuracy: 0.7914 - val_loss: 0.5561
# Epoch 17/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7529 - loss: 0.5844 - val_accuracy: 0.8086 - val_loss: 0.5450
# Epoch 18/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7776 - loss: 0.5596 - val_accuracy: 0.8143 - val_loss: 0.5340
# Epoch 19/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7694 - loss: 0.5470 - val_accuracy: 0.8257 - val_loss: 0.5244
# Epoch 20/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7765 - loss: 0.5663 - val_accuracy: 0.8257 - val_loss: 0.5184
# Epoch 21/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7565 - loss: 0.5698 - val_accuracy: 0.8314 - val_loss: 0.5124
# Epoch 22/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7800 - loss: 0.5179 - val_accuracy: 0.8343 - val_loss: 0.5080
# Epoch 23/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7635 - loss: 0.5721 - val_accuracy: 0.8314 - val_loss: 0.5041
# Epoch 24/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7835 - loss: 0.5332 - val_accuracy: 0.8257 - val_loss: 0.4997
# Epoch 25/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7824 - loss: 0.5515 - val_accuracy: 0.8229 - val_loss: 0.4972
# Epoch 26/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7894 - loss: 0.5312 - val_accuracy: 0.8229 - val_loss: 0.4935
# Epoch 27/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7812 - loss: 0.5378 - val_accuracy: 0.8200 - val_loss: 0.4899
# Epoch 28/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7835 - loss: 0.5104 - val_accuracy: 0.8200 - val_loss: 0.4878
# Epoch 29/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7859 - loss: 0.5378 - val_accuracy: 0.8229 - val_loss: 0.4860
# Epoch 30/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7906 - loss: 0.5261 - val_accuracy: 0.8229 - val_loss: 0.4837
# Epoch 31/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7918 - loss: 0.5087 - val_accuracy: 0.8229 - val_loss: 0.4818
# Epoch 32/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7894 - loss: 0.5242 - val_accuracy: 0.8229 - val_loss: 0.4811
# Epoch 33/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7718 - loss: 0.5404 - val_accuracy: 0.8229 - val_loss: 0.4796
# Epoch 34/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7929 - loss: 0.5223 - val_accuracy: 0.8229 - val_loss: 0.4776
# Epoch 35/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7906 - loss: 0.5145 - val_accuracy: 0.8257 - val_loss: 0.4761
# Epoch 36/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8024 - loss: 0.4938 - val_accuracy: 0.8257 - val_loss: 0.4744
# Epoch 37/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7835 - loss: 0.5121 - val_accuracy: 0.8229 - val_loss: 0.4719
# Epoch 38/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7847 - loss: 0.5050 - val_accuracy: 0.8257 - val_loss: 0.4696
# Epoch 39/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7882 - loss: 0.5037 - val_accuracy: 0.8257 - val_loss: 0.4681
# Epoch 40/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7894 - loss: 0.5223 - val_accuracy: 0.8257 - val_loss: 0.4662
# Epoch 41/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8165 - loss: 0.4910 - val_accuracy: 0.8257 - val_loss: 0.4649
# Epoch 42/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8141 - loss: 0.4895 - val_accuracy: 0.8257 - val_loss: 0.4640
# Epoch 43/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8082 - loss: 0.4751 - val_accuracy: 0.8257 - val_loss: 0.4636
# Epoch 44/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7835 - loss: 0.4971 - val_accuracy: 0.8257 - val_loss: 0.4625
# Epoch 45/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7918 - loss: 0.5012 - val_accuracy: 0.8286 - val_loss: 0.4609
# Epoch 46/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7953 - loss: 0.4923 - val_accuracy: 0.8286 - val_loss: 0.4594
# Epoch 47/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8035 - loss: 0.5066 - val_accuracy: 0.8286 - val_loss: 0.4598
# Epoch 48/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7847 - loss: 0.5268 - val_accuracy: 0.8286 - val_loss: 0.4579
# Epoch 49/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8047 - loss: 0.5065 - val_accuracy: 0.8314 - val_loss: 0.4566
# Epoch 50/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8059 - loss: 0.4711 - val_accuracy: 0.8286 - val_loss: 0.4556
# Epoch 51/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8035 - loss: 0.4814 - val_accuracy: 0.8286 - val_loss: 0.4553
# Epoch 52/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7976 - loss: 0.4952 - val_accuracy: 0.8257 - val_loss: 0.4549
# Epoch 53/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8012 - loss: 0.4598 - val_accuracy: 0.8257 - val_loss: 0.4537
# Epoch 54/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8071 - loss: 0.5005 - val_accuracy: 0.8257 - val_loss: 0.4538
# Epoch 55/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8059 - loss: 0.4871 - val_accuracy: 0.8286 - val_loss: 0.4532
# Epoch 56/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8188 - loss: 0.4664 - val_accuracy: 0.8286 - val_loss: 0.4528
# Epoch 57/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8035 - loss: 0.4976 - val_accuracy: 0.8314 - val_loss: 0.4520
# Epoch 58/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8200 - loss: 0.4814 - val_accuracy: 0.8314 - val_loss: 0.4517
# Epoch 59/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8176 - loss: 0.4732 - val_accuracy: 0.8286 - val_loss: 0.4516
# Epoch 60/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8200 - loss: 0.4640 - val_accuracy: 0.8314 - val_loss: 0.4505
# Epoch 61/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7906 - loss: 0.4979 - val_accuracy: 0.8314 - val_loss: 0.4499
# Epoch 62/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8153 - loss: 0.4500 - val_accuracy: 0.8286 - val_loss: 0.4501
# Epoch 63/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8035 - loss: 0.4716 - val_accuracy: 0.8286 - val_loss: 0.4500
# Epoch 64/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8235 - loss: 0.4672 - val_accuracy: 0.8314 - val_loss: 0.4490
# Epoch 65/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8165 - loss: 0.4740 - val_accuracy: 0.8343 - val_loss: 0.4487
# Epoch 66/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8000 - loss: 0.4790 - val_accuracy: 0.8343 - val_loss: 0.4484
# Epoch 67/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8059 - loss: 0.4708 - val_accuracy: 0.8286 - val_loss: 0.4475
# Epoch 68/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8141 - loss: 0.4686 - val_accuracy: 0.8314 - val_loss: 0.4472
# Epoch 69/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8271 - loss: 0.4612 - val_accuracy: 0.8343 - val_loss: 0.4465
# Epoch 70/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8071 - loss: 0.4611 - val_accuracy: 0.8343 - val_loss: 0.4465
# Epoch 71/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8212 - loss: 0.4630 - val_accuracy: 0.8343 - val_loss: 0.4458
# Epoch 72/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8082 - loss: 0.4730 - val_accuracy: 0.8343 - val_loss: 0.4453
# Epoch 73/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8259 - loss: 0.4435 - val_accuracy: 0.8314 - val_loss: 0.4448
# Epoch 74/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8224 - loss: 0.4764 - val_accuracy: 0.8371 - val_loss: 0.4443
# Epoch 75/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8294 - loss: 0.4589 - val_accuracy: 0.8371 - val_loss: 0.4447
# Epoch 76/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8165 - loss: 0.4549 - val_accuracy: 0.8371 - val_loss: 0.4445
# Epoch 77/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8153 - loss: 0.4528 - val_accuracy: 0.8371 - val_loss: 0.4439
# Epoch 78/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8094 - loss: 0.4893 - val_accuracy: 0.8457 - val_loss: 0.4441
# Epoch 79/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8224 - loss: 0.4458 - val_accuracy: 0.8457 - val_loss: 0.4439
# Epoch 80/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8153 - loss: 0.4650 - val_accuracy: 0.8486 - val_loss: 0.4432
# Epoch 81/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8141 - loss: 0.4626 - val_accuracy: 0.8429 - val_loss: 0.4425
# Epoch 82/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8318 - loss: 0.4550 - val_accuracy: 0.8457 - val_loss: 0.4426
# Epoch 83/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8353 - loss: 0.4305 - val_accuracy: 0.8457 - val_loss: 0.4423
# Epoch 84/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8188 - loss: 0.4591 - val_accuracy: 0.8429 - val_loss: 0.4418
# Epoch 85/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8224 - loss: 0.4434 - val_accuracy: 0.8400 - val_loss: 0.4412
# Epoch 86/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8176 - loss: 0.4600 - val_accuracy: 0.8400 - val_loss: 0.4412
# Epoch 87/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8176 - loss: 0.4562 - val_accuracy: 0.8400 - val_loss: 0.4409
# Epoch 88/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8400 - loss: 0.4298 - val_accuracy: 0.8400 - val_loss: 0.4403
# Epoch 89/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8106 - loss: 0.4716 - val_accuracy: 0.8400 - val_loss: 0.4404
# Epoch 90/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8341 - loss: 0.4576 - val_accuracy: 0.8429 - val_loss: 0.4401
# Epoch 91/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8094 - loss: 0.4593 - val_accuracy: 0.8457 - val_loss: 0.4402
# Epoch 92/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8200 - loss: 0.4508 - val_accuracy: 0.8457 - val_loss: 0.4402
# Epoch 93/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8188 - loss: 0.4873 - val_accuracy: 0.8429 - val_loss: 0.4404
# Epoch 94/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8341 - loss: 0.4342 - val_accuracy: 0.8429 - val_loss: 0.4398
# Epoch 95/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8494 - loss: 0.4164 - val_accuracy: 0.8457 - val_loss: 0.4392
# Epoch 96/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8294 - loss: 0.4458 - val_accuracy: 0.8457 - val_loss: 0.4391
# Epoch 97/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8318 - loss: 0.4392 - val_accuracy: 0.8457 - val_loss: 0.4391
# Epoch 98/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8365 - loss: 0.4377 - val_accuracy: 0.8457 - val_loss: 0.4390
# Epoch 99/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8282 - loss: 0.4471 - val_accuracy: 0.8457 - val_loss: 0.4390
# Epoch 100/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8318 - loss: 0.4489 - val_accuracy: 0.8486 - val_loss: 0.4389
# Epoch 101/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8306 - loss: 0.4238 - val_accuracy: 0.8486 - val_loss: 0.4390
# Epoch 102/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8353 - loss: 0.4424 - val_accuracy: 0.8486 - val_loss: 0.4387
# Epoch 103/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8200 - loss: 0.4548 - val_accuracy: 0.8486 - val_loss: 0.4383
# Epoch 104/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8035 - loss: 0.4792 - val_accuracy: 0.8486 - val_loss: 0.4379
# Epoch 105/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8435 - loss: 0.4393 - val_accuracy: 0.8486 - val_loss: 0.4383
# Epoch 106/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8365 - loss: 0.4128 - val_accuracy: 0.8486 - val_loss: 0.4380
# Epoch 107/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8235 - loss: 0.4580 - val_accuracy: 0.8486 - val_loss: 0.4380
# Epoch 108/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8306 - loss: 0.4299 - val_accuracy: 0.8457 - val_loss: 0.4383
# Epoch 109/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8376 - loss: 0.4306 - val_accuracy: 0.8486 - val_loss: 0.4375
# Epoch 110/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8224 - loss: 0.4405 - val_accuracy: 0.8457 - val_loss: 0.4377
# Epoch 111/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8353 - loss: 0.4234 - val_accuracy: 0.8486 - val_loss: 0.4377
# Epoch 112/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8271 - loss: 0.4276 - val_accuracy: 0.8457 - val_loss: 0.4373
# Epoch 113/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8188 - loss: 0.4504 - val_accuracy: 0.8457 - val_loss: 0.4377
# Epoch 114/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8376 - loss: 0.4123 - val_accuracy: 0.8457 - val_loss: 0.4375
# Epoch 115/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8376 - loss: 0.4351 - val_accuracy: 0.8457 - val_loss: 0.4371
# Epoch 116/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8412 - loss: 0.4380 - val_accuracy: 0.8457 - val_loss: 0.4369
# Epoch 117/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8400 - loss: 0.4139 - val_accuracy: 0.8429 - val_loss: 0.4371
# Epoch 118/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8588 - loss: 0.4033 - val_accuracy: 0.8429 - val_loss: 0.4369
# Epoch 119/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8494 - loss: 0.3904 - val_accuracy: 0.8429 - val_loss: 0.4370
# Epoch 120/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8459 - loss: 0.4275 - val_accuracy: 0.8429 - val_loss: 0.4370
# Epoch 121/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8318 - loss: 0.4364 - val_accuracy: 0.8457 - val_loss: 0.4377
# Epoch 122/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8212 - loss: 0.4377 - val_accuracy: 0.8457 - val_loss: 0.4379
# Epoch 123/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8294 - loss: 0.4528 - val_accuracy: 0.8457 - val_loss: 0.4376
# Epoch 124/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8388 - loss: 0.4151 - val_accuracy: 0.8457 - val_loss: 0.4371
# Epoch 125/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8400 - loss: 0.4249 - val_accuracy: 0.8429 - val_loss: 0.4371
# Epoch 126/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8306 - loss: 0.4272 - val_accuracy: 0.8429 - val_loss: 0.4366
# Epoch 127/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8412 - loss: 0.4293 - val_accuracy: 0.8457 - val_loss: 0.4364
# Epoch 128/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8435 - loss: 0.4102 - val_accuracy: 0.8457 - val_loss: 0.4366
# Epoch 129/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8318 - loss: 0.4198 - val_accuracy: 0.8429 - val_loss: 0.4370
# Epoch 130/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8329 - loss: 0.4257 - val_accuracy: 0.8429 - val_loss: 0.4371
# Epoch 131/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8318 - loss: 0.4174 - val_accuracy: 0.8457 - val_loss: 0.4366
# Epoch 132/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8318 - loss: 0.4288 - val_accuracy: 0.8457 - val_loss: 0.4365
# Epoch 133/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8471 - loss: 0.4086 - val_accuracy: 0.8457 - val_loss: 0.4367
# Epoch 134/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8400 - loss: 0.4170 - val_accuracy: 0.8457 - val_loss: 0.4366
# Epoch 135/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8424 - loss: 0.4323 - val_accuracy: 0.8457 - val_loss: 0.4363
# Epoch 136/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8259 - loss: 0.4184 - val_accuracy: 0.8457 - val_loss: 0.4364
# Epoch 137/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8494 - loss: 0.4159 - val_accuracy: 0.8457 - val_loss: 0.4360
# Epoch 138/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8388 - loss: 0.4177 - val_accuracy: 0.8486 - val_loss: 0.4358
# Epoch 139/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8494 - loss: 0.3943 - val_accuracy: 0.8514 - val_loss: 0.4357
# Epoch 140/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8424 - loss: 0.4082 - val_accuracy: 0.8514 - val_loss: 0.4359
# Epoch 141/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8424 - loss: 0.4166 - val_accuracy: 0.8543 - val_loss: 0.4363
# Epoch 142/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8329 - loss: 0.4428 - val_accuracy: 0.8543 - val_loss: 0.4364
# Epoch 143/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8659 - loss: 0.3895 - val_accuracy: 0.8543 - val_loss: 0.4367
# Epoch 144/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8353 - loss: 0.4010 - val_accuracy: 0.8543 - val_loss: 0.4367
# Epoch 145/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8541 - loss: 0.4054 - val_accuracy: 0.8543 - val_loss: 0.4364
# Epoch 146/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8282 - loss: 0.4248 - val_accuracy: 0.8543 - val_loss: 0.4365
# Epoch 147/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8353 - loss: 0.4199 - val_accuracy: 0.8543 - val_loss: 0.4367
# Epoch 148/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8365 - loss: 0.4015 - val_accuracy: 0.8543 - val_loss: 0.4369
# Epoch 149/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8459 - loss: 0.4102 - val_accuracy: 0.8543 - val_loss: 0.4366

# %% [markdown]
# - 학습 곡선을 확인합니다.

# %%
# 학습 곡선 확인
dl_history_plot(history2.history)

# %% [markdown]
# - 검증 데이터로 예측 및 평가를 수행합니다.

# %%
# 검증 데이터 평가
y_pred2 = model2.predict(x_val)
y_pred2 = (y_pred2 > 0.5).astype(int)

print(classification_report(y_val, y_pred2))
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.81      0.86       191
#            1       0.80      0.90      0.85       159
#
#     accuracy                           0.85       350
#    macro avg       0.85      0.86      0.85       350
# weighted avg       0.86      0.85      0.85       350

# %% [markdown]
# ### (4) 방법 3: 미세조정
#
# - 기본 모델의 앞쪽 레이어 일부의 학습 기능을 비활성화합니다.
# - 기본 모델을 기반으로 레이어를 추가한 모델을 선언합니다.
# - 추가 학습을 진행한 뒤 성능을 확인합니다.

# %%
# 방법 3: Fine-tuning
clear_session()

# 기본 모델 불러오기
base_model_ft = load_model(path + 'base_model.keras')

# 원본 모델의 출력층 제거
base_model_ft.pop()

# 기본 모델의 모든 레이어를 동결 (feature extractor로 사용)
for layer in base_model_ft.layers:
    layer.trainable = False

# 새로운 출력층을 추가하여 Fine-tuning 모델 구성
model3 = Sequential([
    base_model_ft,
    Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.001)), # 새로운 은닉층 추가
    Dropout(0.3),
    Dense(1, activation='sigmoid') # 새로운 출력층
])

model3.summary()

# %%
# 방법 3: Fine-tuning
clear_session()

# 이전 단계에서 선택된 더 좋은 모델 불러오기
base_model_ft = load_model(path + 'fine_tuning_base_model.keras')

# 원본 모델의 출력층 제거 (새로운 출력층을 추가하기 위함)
# 모델에 따라 출력층이 여러 개일 수 있으므로, 마지막 출력층을 가정합니다.
# 만약 모델 구조가 복잡하여 pop()으로 출력층 제거가 어렵다면, 새로운 Sequential 모델을 구성해야 합니다.
if base_model_ft.layers:
    base_model_ft.pop()

# 기본 모델의 모든 레이어를 동결 (feature extractor로 사용)
for layer in base_model_ft.layers:
    layer.trainable = False

# 새로운 출력층을 추가하여 Fine-tuning 모델 구성
model3 = Sequential([
    base_model_ft,
    Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.001)), # 새로운 은닉층 추가
    Dropout(0.3),
    Dense(1, activation='sigmoid') # 새로운 출력층
])

model3.summary()

# %% [markdown]
# - 학습 방법을 설정하고 학습을 수행합니다.

# %%
# 학습 설정 및 수행 - new_train 데이터만 사용
model3.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history3 = model3.fit(x_train_new_data, y_train_new_data, epochs=200, batch_size=32, validation_data=(x_val, y_val), callbacks=[es], verbose=1, class_weight=class_weight_dict_new_data)

# %% [markdown]
# - 학습 곡선을 확인합니다.

# %%
# 학습 곡선 확인
dl_history_plot(history3.history)

# %% [markdown]
# - 검증 데이터로 예측 및 평가를 수행합니다.

# %%
# 검증 데이터 평가
y_pred3 = model3.predict(x_val)
y_pred3_class = (y_pred3 > 0.5).astype(int)


print(classification_report(y_val, y_pred3_class))
